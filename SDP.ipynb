# %%
import pandas as pd
import copy

# %%
xls = pd.ExcelFile('Cricket Data Set.xlsx')
xls

# %%
print(len(xls.sheet_names))
xls.sheet_names

# %%
df_names = ['_'.join(sheet_names.lower().split()) + '_df' for sheet_names in xls.sheet_names]
print(len(df_names))
df_names

# %%
df_dict = {df_names[sheet_index] : pd.read_excel(xls,sheet_index) for sheet_index in range(len(df_names))}
df_dict.keys()

# %%
for df_name in df_names:
    print(df_name)
    display(df_dict[df_name].head(5))

# %%
df_dict['control_sheet_df'].head(30)

# %%
df_dict['control_sheet_df'].rename({'Unnamed: 0': 'Shot Type'}, axis=1, inplace=True)
df_dict['control_sheet_df'].drop('Unnamed: 1',axis = 1, inplace = True)

# %%
df_dict['control_sheet_df'].head(30)

# %%
df_dict['control_sheet_df'].shape

# %%
for row_index in range(8,df_dict['control_sheet_df'].shape[0],9):
    print(row_index)

# %%
df_dict['control_sheet_df'].isna().sum()

# %%
df_dict['control_sheet_df'] = df_dict['control_sheet_df'].dropna(how='all') 
df_dict['control_sheet_df'].isna().sum()

# %%
df_dict['parameters_df']

# %%
shot_type = df_dict['control_sheet_df'].pop('Shot Type')

# %%
shot_type

# %%
shot_type.value_counts()

# %%
shot_type.isna().sum()

# %%
shot_type_temp = copy.deepcopy(shot_type)
shot_type_temp

# %%
for index,value in shot_type_temp.items():
    if type(value) != str:
        shot_type_temp[index] = shot_type_temp[index-1] 
shot_type_temp

# %%
shot_type_temp.value_counts()

# %%
shot_type = shot_type_temp
shot_type.value_counts()

# %%
df_dict['control_sheet_df'].shape

# %%
ball_type_df = df_dict['parameters_df'].loc[:,['Ball Type','ball symbol']].dropna()
ball_type_dict = dict(zip(ball_type_df['ball symbol'],ball_type_df['Ball Type']))
ball_type_dict

# %%
print(df_dict['control_sheet_df'].columns)
df_dict['control_sheet_df'].rename(columns = {'Sl':'SL'}, inplace = True)
df_dict['control_sheet_df'].columns

# %%
def generate_ballwise_df(df = df_dict['control_sheet_df']):
    for col_index in range(0,df.shape[1],3):
        ball_symbol = df.iloc[:,col_index:col_index+3].columns[0]
        ball_type = ball_type_dict[ball_symbol]
    
        df_dict[f'{ball_type}_shots_df'] = df.iloc[:,col_index:col_index+3]
        df_dict[f'{ball_type}_shots_df'].columns = ['Runs Scored', 'Correct execution of shot according to the ball', 'Effectiveness of the shot execution']
        df_dict[f'{ball_type}_shots_df'].insert(0, 'Ball Type', ball_symbol)
        df_dict[f'{ball_type}_shots_df'].insert(1,'Shot Type', shot_type)

# %%
generate_ballwise_df()

# %%
for df_name in df_dict.keys():
    print(df_name)
    display(df_dict[df_name].head(10))

# %%
df_dict['analysis_parameters_df'] = df_dict['analysis_parameters_df'].dropna(how = 'all')
df_dict['analysis_parameters_df'].reset_index(drop = True, inplace = True)

# %%
pd.set_option('display.max_colwidth', None)
df_dict['analysis_parameters_df']

# %%
def unique_values(df):
    unique_vals = [(col,list(df[col].unique())) for col in df.columns if col!='Sno']
    return unique_vals

# %%
for df_name in df_dict.keys():
    if 'vs' not in df_name:
        continue 
    print(df_name)
    for col,vals in unique_values(df_dict[df_name]):
        print(f'{col} : {vals}')
    print()

# %%
for df_name in df_dict.keys():
    if 'vs' in df_name:
        continue 
    print(df_name)
    for col,vals in unique_values(df_dict[df_name]):
        print(f'{col} : {vals}')
    print()

# %%
for df_name in df_dict.keys():
    if 'vs' not in df_name:
        continue
    print(df_name)
    print(df_dict[df_name][df_dict[df_name]['Dismissal kind'].notnull()])

# %%
df_dict['ind_vs_afg_df']['Dismissal kind'] = df_dict['ind_vs_afg_df']['Dismissal kind'].replace('Leg Stump', 'B')
df_dict['ind_vs_afg_df']['Dismissal kind'] = df_dict['ind_vs_afg_df']['Dismissal kind'].replace('Stump Out', 'St')

# %%
df_dict['ind_vs_afg_df'].loc[df_dict['ind_vs_afg_df']['Dismissal kind'].notnull() & df_dict['ind_vs_afg_df']['Wicket'].isna(),'Wicket'] = 'Wicket'

# %%
def clean_missing_values(df):
    cols_nan = [col_name for col_name, nan_count in df.isna().sum().items() if nan_count!=0 ]
    unary_cols = ['Pitch Type', 'Match ID']
    binary_cols = ['Wide', 'No ball', 'Wicket', 'Hit the Bat']
    
    for col in cols_nan:
        if col in unary_cols:
            df.drop(col, axis = 1, inplace = True)
            continue
        elif col in binary_cols:
            df[col] = df[col].notnull().astype('float')
            continue
        
        df[col].fillna(value = 0, inplace = True)
    
    return df

# %%
def drop_incorrect_data(df,column_name,child_values,parent_values):
    if all(value in parent_values for x in child_values):
        return

    incorrect_values = [val for val in child_values if val not in parent_values]
    df.drop(df[df[column_name].isin(incorrect_values)].index, inplace=True)
    return

# %%
def validate_column_values(df):
    ball_symbol_list = df_dict['parameters_df']['ball symbol'].dropna().tolist()
    ball_symbol_list = list(map(lambda x: x.upper(),ball_symbol_list))
    
    shot_symbol_list = df_dict['parameters_df']['shot symbol'].dropna().tolist()
    shot_symbol_list = list(map(lambda x: x.upper(),shot_symbol_list))
    
    dismissal_symbol_list = df_dict['parameters_df']['dismisal symbol'].dropna().tolist()
    dismissal_symbol_list = list(map(lambda x: x.upper(),dismissal_symbol_list))
    dismissal_dict = dict(zip(df_dict['parameters_df']['Dismissal Kind'].dropna(),df_dict['parameters_df']['dismisal symbol'].dropna()))
    
    control_values_list = [0.0,1.0]
    effectiveness_values_list = [x/10.0 for x in range(0,11)] + [-1.0]

    for col_name, col_values in unique_values(df):
        if 'shot' in col_name.lower():
            col_values = list(map(lambda x: x.upper(), col_values))
            drop_incorrect_data(df,col_name,col_values,shot_symbol_list)
        elif col_name.lower() == 'ball type':
            col_values = list(map(lambda x: x.upper(), col_values))
            drop_incorrect_data(df,col_name,col_values,ball_symbol_list)
        elif 'control' in col_name.lower():
            df[col_name] = df[col_name].replace(-1.0,0.0) if -1.0 in col_values else df[col_name]
            col_values.remove(-1.0) if -1.0 in col_values else col_values
            drop_incorrect_data(df,col_name,col_values,control_values_list)
        elif 'effectiveness' in col_name.lower():
            drop_incorrect_data(df,col_name,col_values,effectiveness_values_list)
        elif 'dismissal' in col_name.lower():
            col_values.remove(0)
            df[col_name] = df[col_name].replace('C','Ct') if 'C' in col_values else df[col_name]
            col_values = ['Ct' if col_value == 'C' else col_value for col_value in col_values]
            
            for col_value in col_values:
                df[col_name] = df[col_name].replace(col_value,dismissal_dict[col_value]) if len(col_value) > 3 else df[col_name
                                                                                                                      ]
            col_values = [dismissal_dict[col_value] if len(col_value) > 3 else col_value for col_value in col_values]
            col_values = [col_value.upper() for col_value in col_values]
            drop_incorrect_data(df,col_name,col_values,dismissal_symbol_list)
    
    return df

# %%
def clean_df(df):
    df.drop('Sno', axis = 1, inplace = True)
    df = df.dropna(how = 'all')
    df.reset_index(drop = True, inplace = True)
    df.rename(columns = {'Player Name':'Batsman Name', 'Player ID':'Batsman Player ID', 'Bowler':'Bowler Name', 'Player ID.1':'Bowler Player ID','X':'Effectiveness'}, inplace = True)
    
    non_nan_df = clean_missing_values(df)    
    validated_df = validate_column_values(non_nan_df)
    
    return validated_df

# %%
length = 0

for df_name in df_dict.keys():
    if 'vs' not in df_name:
        continue 
    length += df_dict[df_name].shape[0]

print(length)

# %%
matches_df = pd.DataFrame()

for df_name in df_dict.keys():
    if 'vs' not in df_name:
        continue
    cleaned_df = clean_df(df_dict[df_name])
    matches_df = pd.concat([matches_df, cleaned_df], ignore_index=True)

matches_df.shape

# %%
for df_name in df_dict.keys():
    if 'vs' not in df_name:
        continue
    print(df_name)
    for col_name, col_values in unique_values(df_dict[df_name]):
        print(col_name, col_values)
    print()

# %%
matches_df

# %%
for col_name, col_values in unique_values(matches_df):
    print(col_name,col_values)

# %%
matches_df.nunique()

# %%
player_info = dict(zip(matches_df['Batsman Name'],matches_df['Batsman Player ID']))
player_info

# %%
len(player_info)

# %%
matches_df['Batsman Name'].replace('Kedar Jadhav','Kedhar Jadhav', inplace = True)
matches_df['Batsman Name'].replace('Shikar Dhawan','Shikhar Dhawan', inplace = True)

# %%
matches_df.nunique()

# %%
df_dict['analysis_parameters_df']

# %%
def off_side_score(df = matches_df):
    off_side_shots = ['DR','C','RS']
    
    off_side_shots_count = df[df['Type of Shot'].isin(off_side_shots)].groupby('Batsman Name').agg(off_side_shots_count = ('Type of Shot', 'count'), sum_effectiveness = ('Effectiveness', 'sum'))
    grouped_df = df.groupby('Batsman Name').agg(total_no_of_balls_faced = ('Type of Shot', 'count'))
    
    off_side_score_df = off_side_shots_count.merge(grouped_df,on = 'Batsman Name')
    off_side_score_df = off_side_score_df.reset_index()
    
    off_side_score_df['Highest percentage of off side shots'] = (off_side_score_df['off_side_shots_count']/off_side_score_df['total_no_of_balls_faced'])*100
    off_side_score_df['Highest effectiveness average of off side shots'] = off_side_score_df['sum_effectiveness']/off_side_score_df['off_side_shots_count']
    off_side_score_df['off_side_score'] = (off_side_score_df['Highest percentage of off side shots']/100) * off_side_score_df['Highest effectiveness average of off side shots']
    
    off_side_score_df = off_side_score_df.sort_values(by=['off_side_score'], ascending=False)
    
    return off_side_score_df.loc[:,['Batsman Name','Highest percentage of off side shots','Highest effectiveness average of off side shots','off_side_score']]

# %%
off_side_score()

# %%
def leg_side_score(df = matches_df):
    leg_side_shots = ['P','ODR','LG','F','S']
    
    leg_side_shots_count = df[df['Type of Shot'].isin(leg_side_shots)].groupby('Batsman Name').agg(leg_side_shots_count = ('Type of Shot', 'count'), sum_effectiveness = ('Effectiveness', 'sum'))
    grouped_df = df.groupby('Batsman Name').agg(total_no_of_balls_faced = ('Type of Shot', 'count'))
    
    leg_side_score_df = leg_side_shots_count.merge(grouped_df,on = 'Batsman Name')
    leg_side_score_df = leg_side_score_df.reset_index()
    
    leg_side_score_df['Highest percentage of leg side shots'] = (leg_side_score_df['leg_side_shots_count']/leg_side_score_df['total_no_of_balls_faced'])*100
    leg_side_score_df['Highest effectiveness average of leg side shots'] = leg_side_score_df['sum_effectiveness']/leg_side_score_df['leg_side_shots_count']
    leg_side_score_df['leg_side_score'] = (leg_side_score_df['Highest percentage of leg side shots']/100) * leg_side_score_df['Highest effectiveness average of leg side shots']
    
    leg_side_score_df = leg_side_score_df.sort_values(by=['leg_side_score'], ascending=False)
    
    return leg_side_score_df.loc[:,['Batsman Name','Highest percentage of leg side shots','Highest effectiveness average of leg side shots','leg_side_score']]

# %%
leg_side_score()

# %%
def bouncy_track_score(df = matches_df):
    bouncy_track_shots = ['D','P','C','L']
    
    bouncy_track_shots_count = df[df['Type of Shot'].isin(bouncy_track_shots)].groupby('Batsman Name').agg(bouncy_track_shots_count = ('Type of Shot', 'count'), sum_effectiveness = ('Effectiveness', 'sum'))
    grouped_df = df.groupby('Batsman Name').agg(total_no_of_balls_faced = ('Type of Shot', 'count'))
    
    bouncy_track_score_df = bouncy_track_shots_count.merge(grouped_df,on = 'Batsman Name')
    bouncy_track_score_df = bouncy_track_score_df.reset_index()
    
    bouncy_track_score_df['Highest percentage of bouncy track shots'] = (bouncy_track_score_df['bouncy_track_shots_count']/bouncy_track_score_df['total_no_of_balls_faced'])*100
    bouncy_track_score_df['Highest effectiveness average of bouncy track shots'] = bouncy_track_score_df['sum_effectiveness']/bouncy_track_score_df['bouncy_track_shots_count']
    bouncy_track_score_df['bouncy_track_score'] = (bouncy_track_score_df['Highest percentage of bouncy track shots']/100) * bouncy_track_score_df['Highest effectiveness average of bouncy track shots']
    
    bouncy_track_score_df = bouncy_track_score_df.sort_values(by=['bouncy_track_score'], ascending=False)
    
    return bouncy_track_score_df.loc[:,['Batsman Name','Highest percentage of bouncy track shots','Highest effectiveness average of bouncy track shots','bouncy_track_score']]

# %%
bouncy_track_score()

# %%
def aggressive_shots_score(df = matches_df):
    aggressive_shots = ['Dr', 'C', 'P', 'Sw', 'RS', 'ODR', 'F', 'R', 'LG', 'SC']
    
    aggressive_shots_count = df[df['Type of Shot'].isin(aggressive_shots)].groupby('Batsman Name').agg(aggressive_shots_count = ('Type of Shot', 'count'), sum_effectiveness = ('Effectiveness', 'sum'))
    grouped_df = df.groupby('Batsman Name').agg(total_no_of_balls_faced = ('Type of Shot', 'count'))
    
    aggressive_score_df = aggressive_shots_count.merge(grouped_df,on = 'Batsman Name')
    aggressive_score_df = aggressive_score_df.reset_index()
    
    aggressive_score_df['Highest percentage of aggressive shots'] = (aggressive_score_df['aggressive_shots_count']/aggressive_score_df['total_no_of_balls_faced'])*100
    aggressive_score_df['Highest effectiveness average of aggressive shots'] = aggressive_score_df['sum_effectiveness']/aggressive_score_df['aggressive_shots_count']
    aggressive_score_df['aggressive_score'] = (aggressive_score_df['Highest percentage of aggressive shots']/100) * aggressive_score_df['Highest effectiveness average of aggressive shots']
    
    aggressive_score_df = aggressive_score_df.sort_values(by=['aggressive_score'], ascending=False)
    
    return aggressive_score_df.loc[:,['Batsman Name','Highest percentage of aggressive shots','Highest effectiveness average of aggressive shots','aggressive_score']]

# %%
aggressive_shots_score()

# %%
def defense_score(df = matches_df):
    defense_shots = ['D','L']
    
    defense_shots_count = df[df['Type of Shot'].isin(defense_shots)].groupby('Batsman Name').agg(defense_shots_count = ('Type of Shot', 'count'), sum_effectiveness = ('Effectiveness', 'sum'))
    grouped_df = df.groupby('Batsman Name').agg(total_no_of_balls_faced = ('Type of Shot', 'count'))
    
    defense_score_df = defense_shots_count.merge(grouped_df,on = 'Batsman Name')
    defense_score_df = defense_score_df.reset_index()
    
    defense_score_df['Highest percentage of defense shots'] = (defense_score_df['defense_shots_count']/defense_score_df['total_no_of_balls_faced'])*100
    defense_score_df['Highest effectiveness average of defense shots'] = defense_score_df['sum_effectiveness']/defense_score_df['defense_shots_count']
    defense_score_df['defense_score'] = (defense_score_df['Highest percentage of defense shots']/100) * defense_score_df['Highest effectiveness average of defense shots']
    
    defense_score_df = defense_score_df.sort_values(by=['defense_score'], ascending=False)
    
    return defense_score_df.loc[:,['Batsman Name','Highest percentage of defense shots','Highest effectiveness average of defense shots','defense_score']]

# %%
defense_score()

# %%
def spin_ball_score(df = matches_df):
    spin_ball_shots = ['D', 'Dr', 'C', 'P', 'Sw', 'RS', 'ODR', 'F', 'R', 'LG', 'SC']
    spin_ball = ['GY', 'LB']
    
    spin_ball_shots_count = df[df['Type of Shot'].isin(spin_ball_shots) & df['Ball type'].isin(spin_ball)].groupby('Batsman Name').agg(spin_ball_shots_count = ('Type of Shot', 'count'), sum_effectiveness = ('Effectiveness', 'sum'))
    grouped_df = df.groupby('Batsman Name').agg(total_no_of_balls_faced = ('Type of Shot', 'count'))
    
    spin_ball_score_df = spin_ball_shots_count.merge(grouped_df,on = 'Batsman Name')
    spin_ball_score_df = spin_ball_score_df.reset_index()
    
    spin_ball_score_df['Highest percentage of spin ball shots'] = (spin_ball_score_df['spin_ball_shots_count']/spin_ball_score_df['total_no_of_balls_faced'])*100
    spin_ball_score_df['Highest effectiveness average of spin ball shots'] = spin_ball_score_df['sum_effectiveness']/spin_ball_score_df['spin_ball_shots_count']
    spin_ball_score_df['spin_ball_score'] = (spin_ball_score_df['Highest percentage of spin ball shots']/100) * spin_ball_score_df['Highest effectiveness average of spin ball shots']
    
    spin_ball_score_df = spin_ball_score_df.sort_values(by=['spin_ball_score'], ascending=False)
    
    return spin_ball_score_df.loc[:,['Batsman Name','Highest percentage of spin ball shots','Highest effectiveness average of spin ball shots','spin_ball_score']]

# %%
spin_ball_score()

# %%
def control_score(df = matches_df):
    shots = ['D', 'Dr', 'C', 'P', 'Sw', 'RS', 'ODR', 'F', 'R', 'LG', 'SC', 'L']
    
    shot_count_df = df[df['Control'] == 1.0].groupby('Batsman Name').agg(controlled_shots_count = ('Type of Shot', 'count'), sum_effectiveness = ('Effectiveness', 'sum'))
    grouped_df = df.groupby('Batsman Name').agg(total_no_of_balls_faced = ('Type of Shot', 'count'))
    
    control_score_df = shot_count_df.merge(grouped_df, on ='Batsman Name')
    control_score_df = control_score_df.reset_index()
    
    control_score_df['Highest percentage of controlled shots'] = (control_score_df['controlled_shots_count']/control_score_df['total_no_of_balls_faced'])*100
    control_score_df['Highest effectiveness average of controlled shots'] = control_score_df['sum_effectiveness']/control_score_df['controlled_shots_count']
    control_score_df['control_score'] = (control_score_df['Highest percentage of controlled shots']/100) * control_score_df['Highest effectiveness average of controlled shots']
    
    control_score_df = control_score_df.sort_values(by=['control_score'], ascending=False)
    
    return control_score_df.loc[:,['Batsman Name','Highest percentage of controlled shots','Highest effectiveness average of controlled shots','control_score']]

# %%
control_score()

# %%
matches_df.info()

# %%
matches_df['Control'].unique()

# %%
matches_df['Control'] = matches_df['Control'].astype('float')

# %%
matches_df.info()

# %%
matches_df['Control'].unique()

# %%
ball_type_dict = dict(zip(df_dict['parameters_df']['ball symbol'],df_dict['parameters_df']['Ball Type']))
ball_type_dict

# %%
shot_count_df = matches_df.groupby(['Ball type', 'Type of Shot']).agg(Count = ('Type of Shot','count'))
shot_count_df = shot_count_df.reset_index()
shot_count_df

# %%
import seaborn as sns
import matplotlib.pyplot as plt

for ball_type in list(matches_df['Ball type'].unique()):
    plt.figure(figsize = (15,5))
    sns.set_style('whitegrid')
    plt.title(f"Shot Type Spread vs {ball_type_dict[ball_type]} ball")
    sns.countplot(x = 'Type of Shot', data = matches_df[matches_df['Ball type'] == ball_type])

# %%
matches_df.columns

# %%
original_matches_df = copy.deepcopy(matches_df)

# %%
original_matches_df

# %%
df_dict['off_side_score_df'] = off_side_score()
df_dict['leg_side_score_df'] = leg_side_score()
df_dict['bouncy_track_score_df'] = bouncy_track_score()
df_dict['aggressive_score_df'] = aggressive_shots_score()
df_dict['defense_score_df'] = defense_score()
df_dict['spin_ball_score_df'] = spin_ball_score()
df_dict['control_score_df'] = control_score()

# %%
for df_name in df_dict.keys():
    if 'score' not in df_name:
        continue
    score_col = df_name[:-3]
    matches_df = pd.merge(matches_df, df_dict[df_name].loc[:,['Batsman Name',score_col]], on = 'Batsman Name')

# %%
matches_df

# %%
categorical_variables = []
continuous_variables = []

for column in matches_df.columns:
    if matches_df[column].dtype != 'object':
        continuous_variables.append(column)
        continue
    categorical_variables.append(column)

print(categorical_variables)
print(continuous_variables)

# %%
from scipy.stats import chi2_contingency

alpha = 0.05

for col in categorical_variables:
    contingency_table = pd.crosstab(matches_df[col], matches_df['Effectiveness'])
    if contingency_table.empty:
        continue
    chi2, p_value, _, _ = chi2_contingency(contingency_table)
    print(f"Column {col}: chi2={chi2}, p_value={p_value}")
    if p_value > alpha:
        print(f"Column {col} is not significantly related to the target and will be removed.")
        matches_df.drop(col, axis=1, inplace=True)
    print()

matches_df

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
for col in matches_df.columns:
    if col not in categorical_variables:
        continue
    matches_df[col] = le.fit_transform(matches_df[col].astype(str))

# %%
matches_df

# %%
for col_name, col_values in unique_values(matches_df):
    print(col_name,col_values)

# %%
corr = matches_df.corr() 

plt.figure(figsize=(10, 10), dpi = 600) 
 
sns.heatmap(corr, cmap="Blues", annot=True, annot_kws={"size": 8})

plt.tick_params(axis = 'x', labelsize = 12) 
plt.tick_params(axis = 'y', labelsize = 12)

# %%
X = matches_df.drop("Effectiveness", axis=1)
y = matches_df['Effectiveness']

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
scaled_X = scaler.fit_transform(X)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(scaled_X, y, test_size=0.20, random_state=42)

# %%
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor
from xgboost import XGBRegressor
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor 
import catboost as cb
from sklearn import svm
from sklearn.metrics import mean_squared_error
import numpy as np

reg1 = svm.SVR(kernel = 'rbf')
reg2 = LinearRegression()
reg3 = RandomForestRegressor()
reg4 = XGBRegressor()
reg5 = LinearRegression()
reg6 = GradientBoostingRegressor()
reg7 = DecisionTreeRegressor()
reg8 = cb.CatBoostRegressor()


score1 = cross_val_score(reg1,X_train,y_train,cv = 5, scoring = 'neg_mean_absolute_error')
score2 = cross_val_score(reg2,X_train,y_train,cv = 5, scoring = 'neg_mean_absolute_error')
score3 = cross_val_score(reg3,X_train,y_train,cv = 5, scoring = 'neg_mean_absolute_error')
score4 = cross_val_score(reg4,X_train,y_train,cv = 5, scoring = 'neg_mean_absolute_error')
score5 = cross_val_score(reg5,X_train,y_train,cv = 5, scoring = 'neg_mean_absolute_error')
score6 = cross_val_score(reg6,X_train,y_train,cv = 5, scoring = 'neg_mean_absolute_error')
score7 = cross_val_score(reg7,X_train,y_train,cv = 5, scoring = 'neg_mean_absolute_error')
score8 = cross_val_score(reg8,X_train,y_train,cv = 5, scoring = 'neg_mean_absolute_error')


print('SVM mean absolute error: ',np.mean(-1*score1))
print('Linear Regression mean absolute error: ',np.mean(-1*score2))
print('Random Forest mean absolute error: ',np.mean(-1*score3))
print('XGBoost mean absolute error: ',np.mean(-1*score4))
print('Linear Regression mean absolute error: ',np.mean(-1*score5))
print('GradientBoosting Regressor mean absolute error: ',np.mean(-1*score6))
print('Decision Tree Regressor mean absolute error: ',np.mean(-1*score7))
print('Cat Boost Regressor mean absolute error: ',np.mean(-1*score8))
# Out:
# Learning rate set to 0.041492
# 0:	learn: 0.3644924	total: 1.18ms	remaining: 1.18s
# 1:	learn: 0.3562463	total: 2.15ms	remaining: 1.07s
# 2:	learn: 0.3481300	total: 3.08ms	remaining: 1.02s
# 3:	learn: 0.3400650	total: 3.81ms	remaining: 950ms
# 4:	learn: 0.3344886	total: 4.47ms	remaining: 890ms
# 5:	learn: 0.3274860	total: 5.32ms	remaining: 882ms
# 6:	learn: 0.3208305	total: 6.24ms	remaining: 885ms
# 7:	learn: 0.3145653	total: 7.1ms	remaining: 880ms
# 8:	learn: 0.3087422	total: 7.94ms	remaining: 874ms
# 9:	learn: 0.3038810	total: 8.78ms	remaining: 869ms
# 10:	learn: 0.2986821	total: 9.6ms	remaining: 863ms
# 11:	learn: 0.2932185	total: 10.4ms	remaining: 860ms
# 12:	learn: 0.2880820	total: 11.3ms	remaining: 857ms
# 13:	learn: 0.2834210	total: 12.2ms	remaining: 862ms
# 14:	learn: 0.2792252	total: 13.1ms	remaining: 859ms
# 15:	learn: 0.2752747	total: 14ms	remaining: 860ms
# 16:	learn: 0.2719233	total: 14.8ms	remaining: 856ms
# 17:	learn: 0.2679534	total: 15.7ms	remaining: 856ms
# 18:	learn: 0.2649640	total: 16.6ms	remaining: 855ms
# 19:	learn: 0.2610199	total: 17.3ms	remaining: 850ms
# 20:	learn: 0.2575467	total: 18.2ms	remaining: 851ms
# 21:	learn: 0.2555628	total: 19.1ms	remaining: 849ms
# 22:	learn: 0.2533773	total: 20ms	remaining: 848ms
# 23:	learn: 0.2499370	total: 20.9ms	remaining: 851ms
# 24:	learn: 0.2466554	total: 21.8ms	remaining: 850ms
# 25:	learn: 0.2438995	total: 22.6ms	remaining: 847ms
# 26:	learn: 0.2411328	total: 23.4ms	remaining: 845ms
# 27:	learn: 0.2388159	total: 24.3ms	remaining: 843ms
# 28:	learn: 0.2367354	total: 25.1ms	remaining: 840ms
# 29:	learn: 0.2353136	total: 26.1ms	remaining: 844ms
# 30:	learn: 0.2337784	total: 27ms	remaining: 843ms
# 31:	learn: 0.2319899	total: 27.9ms	remaining: 846ms
# 32:	learn: 0.2296599	total: 28.8ms	remaining: 844ms
# 33:	learn: 0.2275074	total: 29.6ms	remaining: 842ms
# 34:	learn: 0.2266322	total: 30.5ms	remaining: 840ms
# 35:	learn: 0.2220949	total: 31.3ms	remaining: 839ms
# 36:	learn: 0.2213018	total: 31.9ms	remaining: 830ms
# 37:	learn: 0.2193753	total: 32.7ms	remaining: 829ms
# 38:	learn: 0.2185182	total: 33.2ms	remaining: 818ms
# 39:	learn: 0.2177850	total: 34ms	remaining: 815ms
# 40:	learn: 0.2146864	total: 34.8ms	remaining: 815ms
# 41:	learn: 0.2140017	total: 35.4ms	remaining: 807ms
# 42:	learn: 0.2129880	total: 36.2ms	remaining: 806ms
# 43:	learn: 0.2115637	total: 37ms	remaining: 805ms
# 44:	learn: 0.2100788	total: 37.9ms	remaining: 805ms
# 45:	learn: 0.2089253	total: 38.8ms	remaining: 805ms
# 46:	learn: 0.2084664	total: 39.7ms	remaining: 805ms
# 47:	learn: 0.2079679	total: 40.5ms	remaining: 802ms
# 48:	learn: 0.2061569	total: 41.5ms	remaining: 805ms
# 49:	learn: 0.2048610	total: 42.4ms	remaining: 805ms
# 50:	learn: 0.2043264	total: 43.3ms	remaining: 806ms
# 51:	learn: 0.2028056	total: 44.2ms	remaining: 806ms
# 52:	learn: 0.2011151	total: 45.1ms	remaining: 806ms
# 53:	learn: 0.2006379	total: 46ms	remaining: 806ms
# 54:	learn: 0.1992916	total: 46.9ms	remaining: 806ms
# 55:	learn: 0.1985782	total: 47.7ms	remaining: 804ms
# 56:	learn: 0.1974608	total: 48.7ms	remaining: 805ms
# 57:	learn: 0.1967573	total: 49.6ms	remaining: 806ms
# 58:	learn: 0.1959208	total: 50.6ms	remaining: 807ms
# 59:	learn: 0.1954330	total: 51.7ms	remaining: 809ms
# 60:	learn: 0.1946031	total: 52.6ms	remaining: 810ms
# 61:	learn: 0.1940885	total: 53.5ms	remaining: 810ms
# 62:	learn: 0.1937115	total: 54.5ms	remaining: 810ms
# 63:	learn: 0.1933688	total: 55.3ms	remaining: 808ms
# 64:	learn: 0.1929061	total: 56.2ms	remaining: 808ms
# 65:	learn: 0.1926106	total: 57ms	remaining: 807ms
# 66:	learn: 0.1916669	total: 58ms	remaining: 807ms
# 67:	learn: 0.1909287	total: 58.8ms	remaining: 806ms
# 68:	learn: 0.1904645	total: 59.7ms	remaining: 805ms
# 69:	learn: 0.1897963	total: 60.6ms	remaining: 805ms
# 70:	learn: 0.1884604	total: 61.4ms	remaining: 804ms
# 71:	learn: 0.1879729	total: 62.2ms	remaining: 802ms
# 72:	learn: 0.1876356	total: 63.1ms	remaining: 801ms
# 73:	learn: 0.1866279	total: 63.9ms	remaining: 800ms
# 74:	learn: 0.1861758	total: 64.8ms	remaining: 799ms
# 75:	learn: 0.1854843	total: 65.6ms	remaining: 798ms
# 76:	learn: 0.1851659	total: 66.6ms	remaining: 798ms
# 77:	learn: 0.1848165	total: 67.5ms	remaining: 798ms
# 78:	learn: 0.1823072	total: 68.5ms	remaining: 798ms
# 79:	learn: 0.1821051	total: 69.2ms	remaining: 796ms
# 80:	learn: 0.1816681	total: 70.1ms	remaining: 795ms
# 81:	learn: 0.1815190	total: 70.7ms	remaining: 791ms
# 82:	learn: 0.1811896	total: 71.5ms	remaining: 790ms
# 83:	learn: 0.1806581	total: 72.4ms	remaining: 789ms
# 84:	learn: 0.1798717	total: 73.2ms	remaining: 788ms
# 85:	learn: 0.1794455	total: 74.1ms	remaining: 787ms
# 86:	learn: 0.1777707	total: 75ms	remaining: 787ms
# 87:	learn: 0.1773753	total: 75.9ms	remaining: 786ms
# 88:	learn: 0.1769123	total: 76.7ms	remaining: 785ms
# 89:	learn: 0.1768081	total: 77.5ms	remaining: 783ms
# 90:	learn: 0.1763167	total: 78.3ms	remaining: 782ms
# 91:	learn: 0.1750593	total: 79.2ms	remaining: 782ms
# 92:	learn: 0.1744085	total: 80.1ms	remaining: 781ms
# 93:	learn: 0.1735677	total: 81ms	remaining: 781ms
# 94:	learn: 0.1707279	total: 81.9ms	remaining: 780ms
# 95:	learn: 0.1703541	total: 82.8ms	remaining: 779ms
# 96:	learn: 0.1699101	total: 83.6ms	remaining: 778ms
# 97:	learn: 0.1695862	total: 84.4ms	remaining: 777ms
# 98:	learn: 0.1674540	total: 85.3ms	remaining: 776ms
# 99:	learn: 0.1671810	total: 86.1ms	remaining: 775ms
# 100:	learn: 0.1658614	total: 86.8ms	remaining: 773ms
# 101:	learn: 0.1638387	total: 87.6ms	remaining: 771ms
# 102:	learn: 0.1633883	total: 88.3ms	remaining: 769ms
# 103:	learn: 0.1631055	total: 89.1ms	remaining: 768ms
# 104:	learn: 0.1607485	total: 90ms	remaining: 768ms
# 105:	learn: 0.1605540	total: 90.9ms	remaining: 766ms
# 106:	learn: 0.1598739	total: 91.7ms	remaining: 765ms
# 107:	learn: 0.1595586	total: 92.6ms	remaining: 765ms
# 108:	learn: 0.1594796	total: 93.5ms	remaining: 764ms
# 109:	learn: 0.1587009	total: 94.4ms	remaining: 764ms
# 110:	learn: 0.1583689	total: 95.2ms	remaining: 762ms
# 111:	learn: 0.1581507	total: 96ms	remaining: 762ms
# 112:	learn: 0.1577268	total: 96.9ms	remaining: 760ms
# 113:	learn: 0.1573339	total: 97.7ms	remaining: 759ms
# 114:	learn: 0.1570500	total: 98.6ms	remaining: 759ms
# 115:	learn: 0.1568603	total: 99.4ms	remaining: 758ms
# 116:	learn: 0.1565574	total: 100ms	remaining: 756ms
# 117:	learn: 0.1562588	total: 101ms	remaining: 756ms
# 118:	learn: 0.1560872	total: 102ms	remaining: 754ms
# 119:	learn: 0.1559332	total: 103ms	remaining: 754ms
# 120:	learn: 0.1558775	total: 104ms	remaining: 753ms
# 121:	learn: 0.1555099	total: 104ms	remaining: 752ms
# 122:	learn: 0.1553149	total: 105ms	remaining: 751ms
# 123:	learn: 0.1550968	total: 106ms	remaining: 750ms
# 124:	learn: 0.1549068	total: 107ms	remaining: 749ms
# 125:	learn: 0.1534921	total: 108ms	remaining: 748ms
# 126:	learn: 0.1533912	total: 109ms	remaining: 748ms
# 127:	learn: 0.1506352	total: 110ms	remaining: 747ms
# 128:	learn: 0.1502331	total: 110ms	remaining: 746ms
# 129:	learn: 0.1500485	total: 111ms	remaining: 745ms
# 130:	learn: 0.1483884	total: 112ms	remaining: 744ms
# 131:	learn: 0.1477203	total: 113ms	remaining: 743ms
# 132:	learn: 0.1456082	total: 114ms	remaining: 742ms
# 133:	learn: 0.1450382	total: 115ms	remaining: 741ms
# 134:	learn: 0.1450090	total: 115ms	remaining: 737ms
# 135:	learn: 0.1444387	total: 116ms	remaining: 737ms
# 136:	learn: 0.1443789	total: 117ms	remaining: 737ms
# 137:	learn: 0.1442882	total: 118ms	remaining: 736ms
# 138:	learn: 0.1440460	total: 119ms	remaining: 735ms
# 139:	learn: 0.1440257	total: 119ms	remaining: 732ms
# 140:	learn: 0.1426326	total: 120ms	remaining: 732ms
# 141:	learn: 0.1412542	total: 121ms	remaining: 731ms
# 142:	learn: 0.1391082	total: 122ms	remaining: 730ms
# 143:	learn: 0.1390540	total: 123ms	remaining: 729ms
# 144:	learn: 0.1387612	total: 123ms	remaining: 728ms
# 145:	learn: 0.1387228	total: 124ms	remaining: 726ms
# 146:	learn: 0.1385585	total: 125ms	remaining: 725ms
# 147:	learn: 0.1383171	total: 126ms	remaining: 724ms
# 148:	learn: 0.1380032	total: 127ms	remaining: 723ms
# 149:	learn: 0.1375825	total: 127ms	remaining: 722ms
# 150:	learn: 0.1375640	total: 128ms	remaining: 719ms
# 151:	learn: 0.1373623	total: 129ms	remaining: 718ms
# 152:	learn: 0.1364874	total: 130ms	remaining: 718ms
# 153:	learn: 0.1362183	total: 130ms	remaining: 717ms
# 154:	learn: 0.1360066	total: 131ms	remaining: 716ms
# 155:	learn: 0.1357690	total: 132ms	remaining: 715ms
# 156:	learn: 0.1356912	total: 133ms	remaining: 714ms
# 157:	learn: 0.1351327	total: 134ms	remaining: 713ms
# 158:	learn: 0.1351156	total: 134ms	remaining: 710ms
# 159:	learn: 0.1343685	total: 135ms	remaining: 709ms
# 160:	learn: 0.1341778	total: 136ms	remaining: 708ms
# 161:	learn: 0.1339714	total: 137ms	remaining: 707ms
# 162:	learn: 0.1337110	total: 137ms	remaining: 706ms
# 163:	learn: 0.1334098	total: 138ms	remaining: 705ms
# 164:	learn: 0.1332733	total: 139ms	remaining: 705ms
# 165:	learn: 0.1329804	total: 140ms	remaining: 704ms
# 166:	learn: 0.1324593	total: 141ms	remaining: 703ms
# 167:	learn: 0.1322799	total: 142ms	remaining: 702ms
# 168:	learn: 0.1321037	total: 143ms	remaining: 701ms
# 169:	learn: 0.1319819	total: 143ms	remaining: 700ms
# 170:	learn: 0.1318491	total: 144ms	remaining: 699ms
# 171:	learn: 0.1316211	total: 145ms	remaining: 698ms
# 172:	learn: 0.1304770	total: 146ms	remaining: 697ms
# 173:	learn: 0.1290071	total: 147ms	remaining: 696ms
# 174:	learn: 0.1289343	total: 147ms	remaining: 695ms
# 175:	learn: 0.1288011	total: 148ms	remaining: 694ms
# 176:	learn: 0.1286719	total: 149ms	remaining: 693ms
# 177:	learn: 0.1285877	total: 150ms	remaining: 692ms
# 178:	learn: 0.1267753	total: 151ms	remaining: 691ms
# 179:	learn: 0.1266287	total: 152ms	remaining: 690ms
# 180:	learn: 0.1250787	total: 152ms	remaining: 689ms
# 181:	learn: 0.1249406	total: 153ms	remaining: 688ms
# 182:	learn: 0.1248115	total: 154ms	remaining: 687ms
# 183:	learn: 0.1246358	total: 155ms	remaining: 686ms
# 184:	learn: 0.1245294	total: 156ms	remaining: 685ms
# 185:	learn: 0.1243596	total: 156ms	remaining: 684ms
# 186:	learn: 0.1231082	total: 157ms	remaining: 683ms
# 187:	learn: 0.1229488	total: 158ms	remaining: 682ms
# 188:	learn: 0.1227720	total: 159ms	remaining: 681ms
# 189:	learn: 0.1224124	total: 160ms	remaining: 680ms
# 190:	learn: 0.1216786	total: 161ms	remaining: 680ms
# 191:	learn: 0.1212670	total: 162ms	remaining: 681ms
# 192:	learn: 0.1202501	total: 163ms	remaining: 681ms
# 193:	learn: 0.1200714	total: 164ms	remaining: 681ms
# 194:	learn: 0.1198589	total: 165ms	remaining: 679ms
# 195:	learn: 0.1195920	total: 165ms	remaining: 679ms
# 196:	learn: 0.1191968	total: 166ms	remaining: 678ms
# 197:	learn: 0.1190701	total: 167ms	remaining: 677ms
# 198:	learn: 0.1188800	total: 168ms	remaining: 676ms
# 199:	learn: 0.1182769	total: 169ms	remaining: 676ms
# 200:	learn: 0.1181574	total: 170ms	remaining: 675ms
# 201:	learn: 0.1180137	total: 171ms	remaining: 674ms
# 202:	learn: 0.1174778	total: 171ms	remaining: 673ms
# 203:	learn: 0.1173442	total: 172ms	remaining: 672ms
# 204:	learn: 0.1166366	total: 173ms	remaining: 671ms
# 205:	learn: 0.1166263	total: 174ms	remaining: 669ms
# 206:	learn: 0.1163631	total: 175ms	remaining: 669ms
# 207:	learn: 0.1153061	total: 175ms	remaining: 668ms
# 208:	learn: 0.1151863	total: 176ms	remaining: 667ms
# 209:	learn: 0.1141318	total: 177ms	remaining: 666ms
# 210:	learn: 0.1137770	total: 178ms	remaining: 665ms
# 211:	learn: 0.1125271	total: 179ms	remaining: 664ms
# 212:	learn: 0.1123978	total: 180ms	remaining: 663ms
# 213:	learn: 0.1120181	total: 180ms	remaining: 663ms
# 214:	learn: 0.1118600	total: 181ms	remaining: 662ms
# 215:	learn: 0.1109730	total: 182ms	remaining: 661ms
# 216:	learn: 0.1100301	total: 183ms	remaining: 660ms
# 217:	learn: 0.1100032	total: 184ms	remaining: 658ms
# 218:	learn: 0.1090824	total: 184ms	remaining: 657ms
# 219:	learn: 0.1090740	total: 185ms	remaining: 656ms
# 220:	learn: 0.1081414	total: 186ms	remaining: 655ms
# 221:	learn: 0.1076049	total: 187ms	remaining: 654ms
# 222:	learn: 0.1071026	total: 187ms	remaining: 653ms
# 223:	learn: 0.1061540	total: 188ms	remaining: 652ms
# 224:	learn: 0.1059893	total: 189ms	remaining: 651ms
# 225:	learn: 0.1057075	total: 190ms	remaining: 650ms
# 226:	learn: 0.1050677	total: 191ms	remaining: 649ms
# 227:	learn: 0.1047743	total: 192ms	remaining: 649ms
# 228:	learn: 0.1039527	total: 192ms	remaining: 648ms
# 229:	learn: 0.1036219	total: 193ms	remaining: 647ms
# 230:	learn: 0.1028946	total: 194ms	remaining: 646ms
# 231:	learn: 0.1024092	total: 195ms	remaining: 645ms
# 232:	learn: 0.1017694	total: 196ms	remaining: 644ms
# 233:	learn: 0.1014220	total: 197ms	remaining: 643ms
# 234:	learn: 0.1012429	total: 197ms	remaining: 642ms
# 235:	learn: 0.1011071	total: 198ms	remaining: 641ms
# 236:	learn: 0.1003993	total: 199ms	remaining: 640ms
# 237:	learn: 0.1000380	total: 200ms	remaining: 639ms
# 238:	learn: 0.0995334	total: 200ms	remaining: 638ms
# 239:	learn: 0.0991926	total: 201ms	remaining: 637ms
# 240:	learn: 0.0988508	total: 202ms	remaining: 636ms
# 241:	learn: 0.0982032	total: 203ms	remaining: 635ms
# 242:	learn: 0.0980858	total: 204ms	remaining: 635ms
# 243:	learn: 0.0977688	total: 205ms	remaining: 634ms
# 244:	learn: 0.0976532	total: 205ms	remaining: 633ms
# 245:	learn: 0.0975239	total: 206ms	remaining: 632ms
# 246:	learn: 0.0973682	total: 207ms	remaining: 631ms
# 247:	learn: 0.0967538	total: 208ms	remaining: 630ms
# 248:	learn: 0.0963398	total: 209ms	remaining: 629ms
# 249:	learn: 0.0960168	total: 209ms	remaining: 628ms
# 250:	learn: 0.0957134	total: 210ms	remaining: 627ms
# 251:	learn: 0.0955015	total: 211ms	remaining: 626ms
# 252:	learn: 0.0949490	total: 212ms	remaining: 625ms
# 253:	learn: 0.0946735	total: 213ms	remaining: 624ms
# 254:	learn: 0.0944798	total: 213ms	remaining: 623ms
# 255:	learn: 0.0939578	total: 214ms	remaining: 622ms
# 256:	learn: 0.0934704	total: 215ms	remaining: 622ms
# 257:	learn: 0.0930439	total: 216ms	remaining: 621ms
# 258:	learn: 0.0928593	total: 217ms	remaining: 620ms
# 259:	learn: 0.0926821	total: 218ms	remaining: 619ms
# 260:	learn: 0.0923945	total: 218ms	remaining: 618ms
# 261:	learn: 0.0919212	total: 219ms	remaining: 617ms
# 262:	learn: 0.0914810	total: 220ms	remaining: 616ms
# 263:	learn: 0.0910783	total: 221ms	remaining: 615ms
# 264:	learn: 0.0910051	total: 222ms	remaining: 615ms
# 265:	learn: 0.0907802	total: 222ms	remaining: 614ms
# 266:	learn: 0.0905810	total: 223ms	remaining: 613ms
# 267:	learn: 0.0904615	total: 224ms	remaining: 612ms
# 268:	learn: 0.0903326	total: 225ms	remaining: 611ms
# 269:	learn: 0.0899064	total: 226ms	remaining: 610ms
# 270:	learn: 0.0892691	total: 226ms	remaining: 609ms
# 271:	learn: 0.0889982	total: 227ms	remaining: 608ms
# 272:	learn: 0.0885899	total: 228ms	remaining: 607ms
# 273:	learn: 0.0882108	total: 229ms	remaining: 607ms
# 274:	learn: 0.0880975	total: 230ms	remaining: 606ms
# 275:	learn: 0.0874716	total: 231ms	remaining: 605ms
# 276:	learn: 0.0872840	total: 231ms	remaining: 604ms
# 277:	learn: 0.0869529	total: 232ms	remaining: 603ms
# 278:	learn: 0.0867471	total: 233ms	remaining: 603ms
# 279:	learn: 0.0865693	total: 234ms	remaining: 602ms
# 280:	learn: 0.0863278	total: 235ms	remaining: 601ms
# 281:	learn: 0.0860819	total: 236ms	remaining: 600ms
# 282:	learn: 0.0856583	total: 236ms	remaining: 599ms
# 283:	learn: 0.0855506	total: 237ms	remaining: 598ms
# 284:	learn: 0.0854454	total: 238ms	remaining: 597ms
# 285:	learn: 0.0852610	total: 239ms	remaining: 596ms
# 286:	learn: 0.0848601	total: 240ms	remaining: 595ms
# 287:	learn: 0.0847416	total: 240ms	remaining: 594ms
# 288:	learn: 0.0845739	total: 241ms	remaining: 593ms
# 289:	learn: 0.0842380	total: 242ms	remaining: 592ms
# 290:	learn: 0.0839204	total: 243ms	remaining: 592ms
# 291:	learn: 0.0837589	total: 244ms	remaining: 591ms
# 292:	learn: 0.0833434	total: 244ms	remaining: 590ms
# 293:	learn: 0.0831382	total: 245ms	remaining: 589ms
# 294:	learn: 0.0827485	total: 246ms	remaining: 588ms
# 295:	learn: 0.0824467	total: 247ms	remaining: 587ms
# 296:	learn: 0.0821558	total: 248ms	remaining: 586ms
# 297:	learn: 0.0818587	total: 248ms	remaining: 585ms
# 298:	learn: 0.0817284	total: 249ms	remaining: 584ms
# 299:	learn: 0.0815830	total: 250ms	remaining: 583ms
# 300:	learn: 0.0813593	total: 251ms	remaining: 583ms
# 301:	learn: 0.0810335	total: 252ms	remaining: 582ms
# 302:	learn: 0.0807242	total: 252ms	remaining: 581ms
# 303:	learn: 0.0805571	total: 253ms	remaining: 580ms
# 304:	learn: 0.0799151	total: 254ms	remaining: 579ms
# 305:	learn: 0.0797420	total: 255ms	remaining: 578ms
# 306:	learn: 0.0796514	total: 256ms	remaining: 577ms
# 307:	learn: 0.0793966	total: 257ms	remaining: 577ms
# 308:	learn: 0.0793091	total: 257ms	remaining: 576ms
# 309:	learn: 0.0791519	total: 258ms	remaining: 575ms
# 310:	learn: 0.0790667	total: 259ms	remaining: 574ms
# 311:	learn: 0.0789153	total: 260ms	remaining: 573ms
# 312:	learn: 0.0787125	total: 261ms	remaining: 572ms
# 313:	learn: 0.0783880	total: 261ms	remaining: 571ms
# 314:	learn: 0.0781546	total: 262ms	remaining: 571ms
# 315:	learn: 0.0779983	total: 263ms	remaining: 570ms
# 316:	learn: 0.0778264	total: 264ms	remaining: 569ms
# 317:	learn: 0.0776932	total: 265ms	remaining: 568ms
# 318:	learn: 0.0770679	total: 266ms	remaining: 567ms
# 319:	learn: 0.0765801	total: 266ms	remaining: 566ms
# 320:	learn: 0.0762756	total: 267ms	remaining: 565ms
# 321:	learn: 0.0761378	total: 268ms	remaining: 565ms
# 322:	learn: 0.0758901	total: 269ms	remaining: 564ms
# 323:	learn: 0.0756467	total: 270ms	remaining: 563ms
# 324:	learn: 0.0755671	total: 271ms	remaining: 562ms
# 325:	learn: 0.0755235	total: 272ms	remaining: 561ms
# 326:	learn: 0.0753070	total: 272ms	remaining: 561ms
# 327:	learn: 0.0752174	total: 273ms	remaining: 560ms
# 328:	learn: 0.0750089	total: 274ms	remaining: 559ms
# 329:	learn: 0.0746795	total: 275ms	remaining: 558ms
# 330:	learn: 0.0744837	total: 276ms	remaining: 557ms
# 331:	learn: 0.0743249	total: 276ms	remaining: 556ms
# 332:	learn: 0.0742383	total: 277ms	remaining: 555ms
# 333:	learn: 0.0740170	total: 278ms	remaining: 555ms
# 334:	learn: 0.0739698	total: 279ms	remaining: 554ms
# 335:	learn: 0.0739065	total: 280ms	remaining: 553ms
# 336:	learn: 0.0738069	total: 280ms	remaining: 552ms
# 337:	learn: 0.0736769	total: 281ms	remaining: 551ms
# 338:	learn: 0.0734729	total: 282ms	remaining: 550ms
# 339:	learn: 0.0732661	total: 283ms	remaining: 549ms
# 340:	learn: 0.0730876	total: 284ms	remaining: 548ms
# 341:	learn: 0.0725254	total: 285ms	remaining: 547ms
# 342:	learn: 0.0724643	total: 285ms	remaining: 547ms
# 343:	learn: 0.0723203	total: 286ms	remaining: 546ms
# 344:	learn: 0.0718781	total: 287ms	remaining: 545ms
# 345:	learn: 0.0717433	total: 288ms	remaining: 544ms
# 346:	learn: 0.0716995	total: 289ms	remaining: 543ms
# 347:	learn: 0.0711971	total: 289ms	remaining: 542ms
# 348:	learn: 0.0711544	total: 290ms	remaining: 541ms
# 349:	learn: 0.0709392	total: 291ms	remaining: 540ms
# 350:	learn: 0.0708843	total: 292ms	remaining: 540ms
# 351:	learn: 0.0708451	total: 293ms	remaining: 539ms
# 352:	learn: 0.0708039	total: 293ms	remaining: 538ms
# 353:	learn: 0.0703268	total: 294ms	remaining: 537ms
# 354:	learn: 0.0702368	total: 295ms	remaining: 536ms
# 355:	learn: 0.0700829	total: 296ms	remaining: 535ms
# 356:	learn: 0.0699328	total: 297ms	remaining: 535ms
# 357:	learn: 0.0698929	total: 298ms	remaining: 534ms
# 358:	learn: 0.0698447	total: 298ms	remaining: 533ms
# 359:	learn: 0.0693889	total: 299ms	remaining: 532ms
# 360:	learn: 0.0691686	total: 300ms	remaining: 531ms
# 361:	learn: 0.0687382	total: 301ms	remaining: 530ms
# 362:	learn: 0.0686997	total: 302ms	remaining: 529ms
# 363:	learn: 0.0685528	total: 302ms	remaining: 528ms
# 364:	learn: 0.0684767	total: 303ms	remaining: 528ms
# 365:	learn: 0.0683316	total: 304ms	remaining: 527ms
# 366:	learn: 0.0680895	total: 305ms	remaining: 526ms
# 367:	learn: 0.0680070	total: 306ms	remaining: 525ms
# 368:	learn: 0.0678736	total: 306ms	remaining: 524ms
# 369:	learn: 0.0676953	total: 307ms	remaining: 523ms
# 370:	learn: 0.0672637	total: 308ms	remaining: 522ms
# 371:	learn: 0.0671271	total: 309ms	remaining: 521ms
# 372:	learn: 0.0669929	total: 310ms	remaining: 520ms
# 373:	learn: 0.0666129	total: 310ms	remaining: 520ms
# 374:	learn: 0.0665816	total: 311ms	remaining: 519ms
# 375:	learn: 0.0664424	total: 312ms	remaining: 518ms
# 376:	learn: 0.0663677	total: 313ms	remaining: 517ms
# 377:	learn: 0.0661984	total: 314ms	remaining: 516ms
# 378:	learn: 0.0660620	total: 314ms	remaining: 515ms
# 379:	learn: 0.0660135	total: 315ms	remaining: 514ms
# 380:	learn: 0.0658445	total: 316ms	remaining: 513ms
# 381:	learn: 0.0658189	total: 317ms	remaining: 513ms
# 382:	learn: 0.0658037	total: 318ms	remaining: 512ms
# 383:	learn: 0.0657343	total: 318ms	remaining: 511ms
# 384:	learn: 0.0655070	total: 319ms	remaining: 510ms
# 385:	learn: 0.0654649	total: 320ms	remaining: 509ms
# 386:	learn: 0.0651001	total: 321ms	remaining: 509ms
# 387:	learn: 0.0648955	total: 322ms	remaining: 508ms
# 388:	learn: 0.0648726	total: 323ms	remaining: 507ms
# 389:	learn: 0.0647550	total: 324ms	remaining: 507ms
# 390:	learn: 0.0645175	total: 325ms	remaining: 506ms
# 391:	learn: 0.0644560	total: 326ms	remaining: 505ms
# 392:	learn: 0.0642954	total: 327ms	remaining: 505ms
# 393:	learn: 0.0641662	total: 328ms	remaining: 504ms
# 394:	learn: 0.0637947	total: 328ms	remaining: 503ms
# 395:	learn: 0.0637622	total: 329ms	remaining: 502ms
# 396:	learn: 0.0634350	total: 330ms	remaining: 501ms
# 397:	learn: 0.0634127	total: 331ms	remaining: 500ms
# 398:	learn: 0.0633139	total: 332ms	remaining: 500ms
# 399:	learn: 0.0632393	total: 332ms	remaining: 499ms
# 400:	learn: 0.0630509	total: 333ms	remaining: 498ms
# 401:	learn: 0.0630118	total: 334ms	remaining: 497ms
# 402:	learn: 0.0629029	total: 335ms	remaining: 496ms
# 403:	learn: 0.0627220	total: 336ms	remaining: 496ms
# 404:	learn: 0.0626861	total: 337ms	remaining: 495ms
# 405:	learn: 0.0625729	total: 338ms	remaining: 494ms
# 406:	learn: 0.0625357	total: 339ms	remaining: 493ms
# 407:	learn: 0.0624965	total: 339ms	remaining: 492ms
# 408:	learn: 0.0622867	total: 340ms	remaining: 492ms
# 409:	learn: 0.0621665	total: 341ms	remaining: 491ms
# 410:	learn: 0.0620595	total: 342ms	remaining: 490ms
# 411:	learn: 0.0619466	total: 343ms	remaining: 489ms
# 412:	learn: 0.0616197	total: 344ms	remaining: 488ms
# 413:	learn: 0.0615974	total: 344ms	remaining: 487ms
# 414:	learn: 0.0614842	total: 345ms	remaining: 486ms
# 415:	learn: 0.0612971	total: 346ms	remaining: 486ms
# 416:	learn: 0.0611523	total: 347ms	remaining: 485ms
# 417:	learn: 0.0610922	total: 348ms	remaining: 484ms
# 418:	learn: 0.0610583	total: 348ms	remaining: 483ms
# 419:	learn: 0.0608953	total: 349ms	remaining: 482ms
# 420:	learn: 0.0607997	total: 350ms	remaining: 481ms
# 421:	learn: 0.0607347	total: 351ms	remaining: 481ms
# 422:	learn: 0.0606346	total: 352ms	remaining: 480ms
# 423:	learn: 0.0604363	total: 352ms	remaining: 479ms
# 424:	learn: 0.0603849	total: 353ms	remaining: 478ms
# 425:	learn: 0.0602824	total: 354ms	remaining: 477ms
# 426:	learn: 0.0602621	total: 355ms	remaining: 476ms
# 427:	learn: 0.0600790	total: 356ms	remaining: 475ms
# 428:	learn: 0.0598897	total: 356ms	remaining: 474ms
# 429:	learn: 0.0598429	total: 357ms	remaining: 474ms
# 430:	learn: 0.0595365	total: 358ms	remaining: 473ms
# 431:	learn: 0.0595040	total: 359ms	remaining: 472ms
# 432:	learn: 0.0594843	total: 360ms	remaining: 471ms
# 433:	learn: 0.0593102	total: 360ms	remaining: 470ms
# 434:	learn: 0.0592966	total: 361ms	remaining: 469ms
# 435:	learn: 0.0592872	total: 362ms	remaining: 468ms
# 436:	learn: 0.0592790	total: 363ms	remaining: 467ms
# 437:	learn: 0.0591778	total: 364ms	remaining: 467ms
# 438:	learn: 0.0590841	total: 365ms	remaining: 466ms
# 439:	learn: 0.0590399	total: 365ms	remaining: 465ms
# 440:	learn: 0.0589422	total: 366ms	remaining: 464ms
# 441:	learn: 0.0588627	total: 367ms	remaining: 463ms
# 442:	learn: 0.0587834	total: 368ms	remaining: 462ms
# 443:	learn: 0.0587178	total: 368ms	remaining: 461ms
# 444:	learn: 0.0585341	total: 369ms	remaining: 461ms
# 445:	learn: 0.0584940	total: 370ms	remaining: 460ms
# 446:	learn: 0.0584080	total: 371ms	remaining: 459ms
# 447:	learn: 0.0583073	total: 372ms	remaining: 458ms
# 448:	learn: 0.0582469	total: 373ms	remaining: 457ms
# 449:	learn: 0.0581872	total: 373ms	remaining: 456ms
# 450:	learn: 0.0580946	total: 374ms	remaining: 456ms
# 451:	learn: 0.0579549	total: 375ms	remaining: 455ms
# 452:	learn: 0.0578076	total: 376ms	remaining: 454ms
# 453:	learn: 0.0576363	total: 377ms	remaining: 453ms
# 454:	learn: 0.0575459	total: 377ms	remaining: 452ms
# 455:	learn: 0.0574156	total: 378ms	remaining: 451ms
# 456:	learn: 0.0572543	total: 379ms	remaining: 450ms
# 457:	learn: 0.0571919	total: 380ms	remaining: 450ms
# 458:	learn: 0.0571229	total: 381ms	remaining: 449ms
# 459:	learn: 0.0569911	total: 382ms	remaining: 448ms
# 460:	learn: 0.0569693	total: 382ms	remaining: 447ms
# 461:	learn: 0.0569065	total: 383ms	remaining: 446ms
# 462:	learn: 0.0568121	total: 384ms	remaining: 445ms
# 463:	learn: 0.0567459	total: 385ms	remaining: 444ms
# 464:	learn: 0.0566432	total: 386ms	remaining: 444ms
# 465:	learn: 0.0563507	total: 386ms	remaining: 443ms
# 466:	learn: 0.0563231	total: 387ms	remaining: 442ms
# 467:	learn: 0.0563172	total: 388ms	remaining: 441ms
# 468:	learn: 0.0561994	total: 389ms	remaining: 440ms
# 469:	learn: 0.0559265	total: 389ms	remaining: 439ms
# 470:	learn: 0.0557671	total: 390ms	remaining: 438ms
# 471:	learn: 0.0557518	total: 391ms	remaining: 437ms
# 472:	learn: 0.0557404	total: 392ms	remaining: 437ms
# 473:	learn: 0.0556795	total: 393ms	remaining: 436ms
# 474:	learn: 0.0555901	total: 394ms	remaining: 435ms
# 475:	learn: 0.0555763	total: 395ms	remaining: 434ms
# 476:	learn: 0.0555663	total: 395ms	remaining: 433ms
# 477:	learn: 0.0554145	total: 396ms	remaining: 433ms
# 478:	learn: 0.0553089	total: 397ms	remaining: 432ms
# 479:	learn: 0.0552099	total: 398ms	remaining: 431ms
# 480:	learn: 0.0551467	total: 399ms	remaining: 430ms
# 481:	learn: 0.0550118	total: 399ms	remaining: 429ms
# 482:	learn: 0.0549991	total: 400ms	remaining: 428ms
# 483:	learn: 0.0549440	total: 401ms	remaining: 427ms
# 484:	learn: 0.0549352	total: 402ms	remaining: 427ms
# 485:	learn: 0.0548159	total: 403ms	remaining: 426ms
# 486:	learn: 0.0547269	total: 403ms	remaining: 425ms
# 487:	learn: 0.0545808	total: 404ms	remaining: 424ms
# 488:	learn: 0.0544396	total: 405ms	remaining: 423ms
# 489:	learn: 0.0543500	total: 406ms	remaining: 422ms
# 490:	learn: 0.0543001	total: 407ms	remaining: 421ms
# 491:	learn: 0.0541999	total: 407ms	remaining: 421ms
# 492:	learn: 0.0540504	total: 408ms	remaining: 420ms
# 493:	learn: 0.0539479	total: 409ms	remaining: 419ms
# 494:	learn: 0.0538501	total: 410ms	remaining: 418ms
# 495:	learn: 0.0538423	total: 410ms	remaining: 417ms
# 496:	learn: 0.0537643	total: 411ms	remaining: 416ms
# 497:	learn: 0.0536787	total: 412ms	remaining: 415ms
# 498:	learn: 0.0536079	total: 413ms	remaining: 415ms
# 499:	learn: 0.0535995	total: 414ms	remaining: 414ms
# 500:	learn: 0.0534771	total: 415ms	remaining: 413ms
# 501:	learn: 0.0533318	total: 415ms	remaining: 412ms
# 502:	learn: 0.0533235	total: 416ms	remaining: 411ms
# 503:	learn: 0.0531897	total: 417ms	remaining: 410ms
# 504:	learn: 0.0531558	total: 418ms	remaining: 410ms
# 505:	learn: 0.0531479	total: 419ms	remaining: 409ms
# 506:	learn: 0.0531403	total: 419ms	remaining: 408ms
# 507:	learn: 0.0529956	total: 420ms	remaining: 407ms
# 508:	learn: 0.0528836	total: 421ms	remaining: 406ms
# 509:	learn: 0.0527334	total: 422ms	remaining: 405ms
# 510:	learn: 0.0526956	total: 423ms	remaining: 404ms
# 511:	learn: 0.0526078	total: 423ms	remaining: 404ms
# 512:	learn: 0.0525274	total: 424ms	remaining: 403ms
# 513:	learn: 0.0524552	total: 425ms	remaining: 402ms
# 514:	learn: 0.0523485	total: 426ms	remaining: 401ms
# 515:	learn: 0.0523329	total: 427ms	remaining: 400ms
# 516:	learn: 0.0521906	total: 428ms	remaining: 400ms
# 517:	learn: 0.0521064	total: 429ms	remaining: 399ms
# 518:	learn: 0.0520631	total: 429ms	remaining: 398ms
# 519:	learn: 0.0520578	total: 430ms	remaining: 397ms
# 520:	learn: 0.0519518	total: 431ms	remaining: 396ms
# 521:	learn: 0.0519055	total: 432ms	remaining: 396ms
# 522:	learn: 0.0518965	total: 433ms	remaining: 395ms
# 523:	learn: 0.0517750	total: 434ms	remaining: 394ms
# 524:	learn: 0.0517291	total: 434ms	remaining: 393ms
# 525:	learn: 0.0516233	total: 435ms	remaining: 392ms
# 526:	learn: 0.0514950	total: 436ms	remaining: 391ms
# 527:	learn: 0.0513639	total: 437ms	remaining: 391ms
# 528:	learn: 0.0513188	total: 438ms	remaining: 390ms
# 529:	learn: 0.0512426	total: 438ms	remaining: 389ms
# 530:	learn: 0.0511742	total: 439ms	remaining: 388ms
# 531:	learn: 0.0511301	total: 440ms	remaining: 387ms
# 532:	learn: 0.0510450	total: 441ms	remaining: 386ms
# 533:	learn: 0.0509203	total: 442ms	remaining: 385ms
# 534:	learn: 0.0508783	total: 443ms	remaining: 385ms
# 535:	learn: 0.0508681	total: 443ms	remaining: 384ms
# 536:	learn: 0.0507578	total: 444ms	remaining: 383ms
# 537:	learn: 0.0506658	total: 445ms	remaining: 382ms
# 538:	learn: 0.0506333	total: 446ms	remaining: 381ms
# 539:	learn: 0.0505282	total: 447ms	remaining: 380ms
# 540:	learn: 0.0504380	total: 447ms	remaining: 380ms
# 541:	learn: 0.0503677	total: 448ms	remaining: 379ms
# 542:	learn: 0.0502619	total: 449ms	remaining: 378ms
# 543:	learn: 0.0502529	total: 450ms	remaining: 377ms
# 544:	learn: 0.0502202	total: 451ms	remaining: 376ms
# 545:	learn: 0.0502134	total: 452ms	remaining: 375ms
# 546:	learn: 0.0502078	total: 452ms	remaining: 375ms
# 547:	learn: 0.0500925	total: 453ms	remaining: 374ms
# 548:	learn: 0.0500861	total: 454ms	remaining: 373ms
# 549:	learn: 0.0499995	total: 455ms	remaining: 372ms
# 550:	learn: 0.0499260	total: 456ms	remaining: 371ms
# 551:	learn: 0.0498037	total: 457ms	remaining: 370ms
# 552:	learn: 0.0497590	total: 457ms	remaining: 370ms
# 553:	learn: 0.0496304	total: 458ms	remaining: 369ms
# 554:	learn: 0.0495605	total: 459ms	remaining: 368ms
# 555:	learn: 0.0493469	total: 460ms	remaining: 367ms
# 556:	learn: 0.0493406	total: 461ms	remaining: 366ms
# 557:	learn: 0.0492742	total: 462ms	remaining: 366ms
# 558:	learn: 0.0491862	total: 463ms	remaining: 365ms
# 559:	learn: 0.0491798	total: 464ms	remaining: 364ms
# 560:	learn: 0.0491415	total: 464ms	remaining: 363ms
# 561:	learn: 0.0490797	total: 465ms	remaining: 363ms
# 562:	learn: 0.0489696	total: 466ms	remaining: 362ms
# 563:	learn: 0.0489282	total: 467ms	remaining: 361ms
# 564:	learn: 0.0488811	total: 468ms	remaining: 360ms
# 565:	learn: 0.0488063	total: 468ms	remaining: 359ms
# 566:	learn: 0.0487483	total: 469ms	remaining: 358ms
# 567:	learn: 0.0486578	total: 470ms	remaining: 358ms
# 568:	learn: 0.0485932	total: 471ms	remaining: 357ms
# 569:	learn: 0.0485017	total: 472ms	remaining: 356ms
# 570:	learn: 0.0484182	total: 473ms	remaining: 355ms
# 571:	learn: 0.0483562	total: 474ms	remaining: 355ms
# 572:	learn: 0.0482832	total: 475ms	remaining: 354ms
# 573:	learn: 0.0482048	total: 476ms	remaining: 353ms
# 574:	learn: 0.0481274	total: 477ms	remaining: 352ms
# 575:	learn: 0.0480407	total: 478ms	remaining: 352ms
# 576:	learn: 0.0479695	total: 479ms	remaining: 351ms
# 577:	learn: 0.0479108	total: 479ms	remaining: 350ms
# 578:	learn: 0.0478448	total: 480ms	remaining: 349ms
# 579:	learn: 0.0477430	total: 481ms	remaining: 348ms
# 580:	learn: 0.0476695	total: 482ms	remaining: 348ms
# 581:	learn: 0.0476462	total: 483ms	remaining: 347ms
# 582:	learn: 0.0476173	total: 484ms	remaining: 346ms
# 583:	learn: 0.0475187	total: 485ms	remaining: 345ms
# 584:	learn: 0.0474292	total: 485ms	remaining: 344ms
# 585:	learn: 0.0473576	total: 486ms	remaining: 344ms
# 586:	learn: 0.0473471	total: 487ms	remaining: 343ms
# 587:	learn: 0.0471465	total: 488ms	remaining: 342ms
# 588:	learn: 0.0470348	total: 489ms	remaining: 341ms
# 589:	learn: 0.0470217	total: 489ms	remaining: 340ms
# 590:	learn: 0.0469662	total: 490ms	remaining: 339ms
# 591:	learn: 0.0467790	total: 491ms	remaining: 339ms
# 592:	learn: 0.0467515	total: 492ms	remaining: 338ms
# 593:	learn: 0.0467087	total: 493ms	remaining: 337ms
# 594:	learn: 0.0466366	total: 494ms	remaining: 336ms
# 595:	learn: 0.0465624	total: 495ms	remaining: 335ms
# 596:	learn: 0.0464399	total: 496ms	remaining: 335ms
# 597:	learn: 0.0463666	total: 496ms	remaining: 334ms
# 598:	learn: 0.0463480	total: 497ms	remaining: 333ms
# 599:	learn: 0.0463073	total: 498ms	remaining: 332ms
# 600:	learn: 0.0462270	total: 499ms	remaining: 331ms
# 601:	learn: 0.0462172	total: 500ms	remaining: 330ms
# 602:	learn: 0.0462049	total: 501ms	remaining: 330ms
# 603:	learn: 0.0461515	total: 501ms	remaining: 329ms
# 604:	learn: 0.0460493	total: 502ms	remaining: 328ms
# 605:	learn: 0.0459749	total: 503ms	remaining: 327ms
# 606:	learn: 0.0459051	total: 504ms	remaining: 326ms
# 607:	learn: 0.0458292	total: 505ms	remaining: 325ms
# 608:	learn: 0.0457632	total: 506ms	remaining: 325ms
# 609:	learn: 0.0457594	total: 506ms	remaining: 324ms
# 610:	learn: 0.0457211	total: 507ms	remaining: 323ms
# 611:	learn: 0.0456946	total: 508ms	remaining: 322ms
# 612:	learn: 0.0456335	total: 509ms	remaining: 321ms
# 613:	learn: 0.0455480	total: 509ms	remaining: 320ms
# 614:	learn: 0.0455451	total: 510ms	remaining: 319ms
# 615:	learn: 0.0453247	total: 511ms	remaining: 319ms
# 616:	learn: 0.0453167	total: 512ms	remaining: 318ms
# 617:	learn: 0.0452516	total: 513ms	remaining: 317ms
# 618:	learn: 0.0452172	total: 513ms	remaining: 316ms
# 619:	learn: 0.0451859	total: 514ms	remaining: 315ms
# 620:	learn: 0.0451494	total: 515ms	remaining: 314ms
# 621:	learn: 0.0451379	total: 516ms	remaining: 313ms
# 622:	learn: 0.0450125	total: 517ms	remaining: 313ms
# 623:	learn: 0.0449647	total: 517ms	remaining: 312ms
# 624:	learn: 0.0449387	total: 518ms	remaining: 311ms
# 625:	learn: 0.0448911	total: 519ms	remaining: 310ms
# 626:	learn: 0.0448443	total: 520ms	remaining: 309ms
# 627:	learn: 0.0447999	total: 521ms	remaining: 308ms
# 628:	learn: 0.0447061	total: 521ms	remaining: 308ms
# 629:	learn: 0.0446166	total: 522ms	remaining: 307ms
# 630:	learn: 0.0445544	total: 523ms	remaining: 306ms
# 631:	learn: 0.0444905	total: 524ms	remaining: 305ms
# 632:	learn: 0.0444515	total: 525ms	remaining: 304ms
# 633:	learn: 0.0443655	total: 526ms	remaining: 303ms
# 634:	learn: 0.0443239	total: 526ms	remaining: 303ms
# 635:	learn: 0.0442588	total: 527ms	remaining: 302ms
# 636:	learn: 0.0442419	total: 528ms	remaining: 301ms
# 637:	learn: 0.0442087	total: 529ms	remaining: 300ms
# 638:	learn: 0.0441501	total: 530ms	remaining: 299ms
# 639:	learn: 0.0440682	total: 530ms	remaining: 298ms
# 640:	learn: 0.0439866	total: 531ms	remaining: 298ms
# 641:	learn: 0.0439801	total: 532ms	remaining: 297ms
# 642:	learn: 0.0439156	total: 533ms	remaining: 296ms
# 643:	learn: 0.0438000	total: 534ms	remaining: 295ms
# 644:	learn: 0.0435964	total: 535ms	remaining: 294ms
# 645:	learn: 0.0435599	total: 535ms	remaining: 293ms
# 646:	learn: 0.0435281	total: 536ms	remaining: 293ms
# 647:	learn: 0.0434684	total: 537ms	remaining: 292ms
# 648:	learn: 0.0434295	total: 538ms	remaining: 291ms
# 649:	learn: 0.0434216	total: 539ms	remaining: 290ms
# 650:	learn: 0.0433786	total: 539ms	remaining: 289ms
# 651:	learn: 0.0432190	total: 540ms	remaining: 288ms
# 652:	learn: 0.0431827	total: 541ms	remaining: 288ms
# 653:	learn: 0.0431210	total: 542ms	remaining: 287ms
# 654:	learn: 0.0431052	total: 543ms	remaining: 286ms
# 655:	learn: 0.0430893	total: 543ms	remaining: 285ms
# 656:	learn: 0.0429560	total: 544ms	remaining: 284ms
# 657:	learn: 0.0429193	total: 545ms	remaining: 283ms
# 658:	learn: 0.0428567	total: 546ms	remaining: 282ms
# 659:	learn: 0.0427563	total: 547ms	remaining: 282ms
# 660:	learn: 0.0427161	total: 547ms	remaining: 281ms
# 661:	learn: 0.0426574	total: 548ms	remaining: 280ms
# 662:	learn: 0.0426506	total: 549ms	remaining: 279ms
# 663:	learn: 0.0424528	total: 550ms	remaining: 278ms
# 664:	learn: 0.0424510	total: 551ms	remaining: 277ms
# 665:	learn: 0.0424358	total: 551ms	remaining: 277ms
# 666:	learn: 0.0424293	total: 552ms	remaining: 276ms
# 667:	learn: 0.0423872	total: 553ms	remaining: 275ms
# 668:	learn: 0.0423117	total: 554ms	remaining: 274ms
# 669:	learn: 0.0422195	total: 555ms	remaining: 273ms
# 670:	learn: 0.0421745	total: 555ms	remaining: 272ms
# 671:	learn: 0.0421342	total: 556ms	remaining: 271ms
# 672:	learn: 0.0420773	total: 557ms	remaining: 271ms
# 673:	learn: 0.0420007	total: 558ms	remaining: 270ms
# 674:	learn: 0.0419709	total: 558ms	remaining: 269ms
# 675:	learn: 0.0417908	total: 559ms	remaining: 268ms
# 676:	learn: 0.0416954	total: 560ms	remaining: 267ms
# 677:	learn: 0.0416556	total: 561ms	remaining: 266ms
# 678:	learn: 0.0415555	total: 562ms	remaining: 266ms
# 679:	learn: 0.0415178	total: 562ms	remaining: 265ms
# 680:	learn: 0.0414853	total: 563ms	remaining: 264ms
# 681:	learn: 0.0414068	total: 564ms	remaining: 263ms
# 682:	learn: 0.0413549	total: 565ms	remaining: 262ms
# 683:	learn: 0.0413024	total: 566ms	remaining: 261ms
# 684:	learn: 0.0411940	total: 566ms	remaining: 260ms
# 685:	learn: 0.0411406	total: 567ms	remaining: 260ms
# 686:	learn: 0.0410614	total: 568ms	remaining: 259ms
# 687:	learn: 0.0409759	total: 569ms	remaining: 258ms
# 688:	learn: 0.0409736	total: 569ms	remaining: 257ms
# 689:	learn: 0.0409580	total: 570ms	remaining: 256ms
# 690:	learn: 0.0409041	total: 571ms	remaining: 255ms
# 691:	learn: 0.0408892	total: 572ms	remaining: 254ms
# 692:	learn: 0.0408826	total: 573ms	remaining: 254ms
# 693:	learn: 0.0408078	total: 573ms	remaining: 253ms
# 694:	learn: 0.0408056	total: 574ms	remaining: 252ms
# 695:	learn: 0.0408035	total: 575ms	remaining: 251ms
# 696:	learn: 0.0407145	total: 576ms	remaining: 250ms
# 697:	learn: 0.0406818	total: 576ms	remaining: 249ms
# 698:	learn: 0.0406136	total: 577ms	remaining: 249ms
# 699:	learn: 0.0405575	total: 578ms	remaining: 248ms
# 700:	learn: 0.0404568	total: 579ms	remaining: 247ms
# 701:	learn: 0.0403549	total: 580ms	remaining: 246ms
# 702:	learn: 0.0403427	total: 580ms	remaining: 245ms
# 703:	learn: 0.0402751	total: 581ms	remaining: 244ms
# 704:	learn: 0.0402002	total: 582ms	remaining: 244ms
# 705:	learn: 0.0401723	total: 583ms	remaining: 243ms
# 706:	learn: 0.0401295	total: 584ms	remaining: 242ms
# 707:	learn: 0.0400754	total: 584ms	remaining: 241ms
# 708:	learn: 0.0400229	total: 585ms	remaining: 240ms
# 709:	learn: 0.0400091	total: 586ms	remaining: 239ms
# 710:	learn: 0.0399788	total: 587ms	remaining: 239ms
# 711:	learn: 0.0399262	total: 588ms	remaining: 238ms
# 712:	learn: 0.0398595	total: 589ms	remaining: 237ms
# 713:	learn: 0.0397662	total: 589ms	remaining: 236ms
# 714:	learn: 0.0397353	total: 590ms	remaining: 235ms
# 715:	learn: 0.0396434	total: 591ms	remaining: 234ms
# 716:	learn: 0.0396315	total: 592ms	remaining: 234ms
# 717:	learn: 0.0395616	total: 593ms	remaining: 233ms
# 718:	learn: 0.0395022	total: 593ms	remaining: 232ms
# 719:	learn: 0.0394588	total: 594ms	remaining: 231ms
# 720:	learn: 0.0394201	total: 595ms	remaining: 230ms
# 721:	learn: 0.0392538	total: 596ms	remaining: 229ms
# 722:	learn: 0.0391949	total: 596ms	remaining: 229ms
# 723:	learn: 0.0391073	total: 597ms	remaining: 228ms
# 724:	learn: 0.0391050	total: 598ms	remaining: 227ms
# 725:	learn: 0.0390239	total: 599ms	remaining: 226ms
# 726:	learn: 0.0389742	total: 600ms	remaining: 225ms
# 727:	learn: 0.0389696	total: 600ms	remaining: 224ms
# 728:	learn: 0.0389234	total: 601ms	remaining: 223ms
# 729:	learn: 0.0388332	total: 602ms	remaining: 223ms
# 730:	learn: 0.0388311	total: 603ms	remaining: 222ms
# 731:	learn: 0.0388291	total: 603ms	remaining: 221ms
# 732:	learn: 0.0387827	total: 604ms	remaining: 220ms
# 733:	learn: 0.0387716	total: 605ms	remaining: 219ms
# 734:	learn: 0.0387659	total: 606ms	remaining: 218ms
# 735:	learn: 0.0387007	total: 606ms	remaining: 218ms
# 736:	learn: 0.0386477	total: 607ms	remaining: 217ms
# 737:	learn: 0.0385984	total: 608ms	remaining: 216ms
# 738:	learn: 0.0385957	total: 609ms	remaining: 215ms
# 739:	learn: 0.0385691	total: 610ms	remaining: 214ms
# 740:	learn: 0.0385111	total: 611ms	remaining: 213ms
# 741:	learn: 0.0384693	total: 611ms	remaining: 213ms
# 742:	learn: 0.0384290	total: 612ms	remaining: 212ms
# 743:	learn: 0.0383588	total: 613ms	remaining: 211ms
# 744:	learn: 0.0383447	total: 614ms	remaining: 210ms
# 745:	learn: 0.0382280	total: 614ms	remaining: 209ms
# 746:	learn: 0.0381926	total: 615ms	remaining: 208ms
# 747:	learn: 0.0381081	total: 616ms	remaining: 208ms
# 748:	learn: 0.0380477	total: 617ms	remaining: 207ms
# 749:	learn: 0.0380015	total: 618ms	remaining: 206ms
# 750:	learn: 0.0379683	total: 618ms	remaining: 205ms
# 751:	learn: 0.0379231	total: 619ms	remaining: 204ms
# 752:	learn: 0.0378462	total: 620ms	remaining: 203ms
# 753:	learn: 0.0377515	total: 621ms	remaining: 203ms
# 754:	learn: 0.0376782	total: 622ms	remaining: 202ms
# 755:	learn: 0.0376442	total: 622ms	remaining: 201ms
# 756:	learn: 0.0375999	total: 623ms	remaining: 200ms
# 757:	learn: 0.0374959	total: 624ms	remaining: 199ms
# 758:	learn: 0.0374519	total: 625ms	remaining: 198ms
# 759:	learn: 0.0374454	total: 626ms	remaining: 198ms
# 760:	learn: 0.0374438	total: 626ms	remaining: 197ms
# 761:	learn: 0.0373792	total: 627ms	remaining: 196ms
# 762:	learn: 0.0373743	total: 628ms	remaining: 195ms
# 763:	learn: 0.0373718	total: 629ms	remaining: 194ms
# 764:	learn: 0.0372844	total: 629ms	remaining: 193ms
# 765:	learn: 0.0372760	total: 630ms	remaining: 192ms
# 766:	learn: 0.0372374	total: 631ms	remaining: 192ms
# 767:	learn: 0.0371998	total: 632ms	remaining: 191ms
# 768:	learn: 0.0371220	total: 632ms	remaining: 190ms
# 769:	learn: 0.0370240	total: 634ms	remaining: 189ms
# 770:	learn: 0.0370086	total: 634ms	remaining: 188ms
# 771:	learn: 0.0369201	total: 635ms	remaining: 188ms
# 772:	learn: 0.0369178	total: 636ms	remaining: 187ms
# 773:	learn: 0.0368399	total: 637ms	remaining: 186ms
# 774:	learn: 0.0367502	total: 638ms	remaining: 185ms
# 775:	learn: 0.0367139	total: 639ms	remaining: 184ms
# 776:	learn: 0.0367064	total: 640ms	remaining: 184ms
# 777:	learn: 0.0367043	total: 641ms	remaining: 183ms
# 778:	learn: 0.0366486	total: 641ms	remaining: 182ms
# 779:	learn: 0.0365520	total: 642ms	remaining: 181ms
# 780:	learn: 0.0364822	total: 643ms	remaining: 180ms
# 781:	learn: 0.0364254	total: 644ms	remaining: 180ms
# 782:	learn: 0.0364231	total: 645ms	remaining: 179ms
# 783:	learn: 0.0363881	total: 646ms	remaining: 178ms
# 784:	learn: 0.0363860	total: 646ms	remaining: 177ms
# 785:	learn: 0.0362944	total: 647ms	remaining: 176ms
# 786:	learn: 0.0362746	total: 648ms	remaining: 175ms
# 787:	learn: 0.0362579	total: 649ms	remaining: 175ms
# 788:	learn: 0.0362049	total: 650ms	remaining: 174ms
# 789:	learn: 0.0361114	total: 651ms	remaining: 173ms
# 790:	learn: 0.0360770	total: 651ms	remaining: 172ms
# 791:	learn: 0.0360403	total: 652ms	remaining: 171ms
# 792:	learn: 0.0360384	total: 653ms	remaining: 170ms
# 793:	learn: 0.0360365	total: 654ms	remaining: 170ms
# 794:	learn: 0.0359826	total: 655ms	remaining: 169ms
# 795:	learn: 0.0359812	total: 656ms	remaining: 168ms
# 796:	learn: 0.0359227	total: 656ms	remaining: 167ms
# 797:	learn: 0.0358498	total: 657ms	remaining: 166ms
# 798:	learn: 0.0358318	total: 658ms	remaining: 166ms
# 799:	learn: 0.0357914	total: 659ms	remaining: 165ms
# 800:	learn: 0.0357502	total: 660ms	remaining: 164ms
# 801:	learn: 0.0357097	total: 661ms	remaining: 163ms
# 802:	learn: 0.0356288	total: 662ms	remaining: 162ms
# 803:	learn: 0.0355785	total: 662ms	remaining: 161ms
# 804:	learn: 0.0355213	total: 663ms	remaining: 161ms
# 805:	learn: 0.0354713	total: 664ms	remaining: 160ms
# 806:	learn: 0.0354379	total: 665ms	remaining: 159ms
# 807:	learn: 0.0354154	total: 666ms	remaining: 158ms
# 808:	learn: 0.0353229	total: 666ms	remaining: 157ms
# 809:	learn: 0.0352852	total: 667ms	remaining: 157ms
# 810:	learn: 0.0352417	total: 668ms	remaining: 156ms
# 811:	learn: 0.0351968	total: 669ms	remaining: 155ms
# 812:	learn: 0.0351516	total: 670ms	remaining: 154ms
# 813:	learn: 0.0351092	total: 671ms	remaining: 153ms
# 814:	learn: 0.0350315	total: 672ms	remaining: 152ms
# 815:	learn: 0.0349989	total: 672ms	remaining: 152ms
# 816:	learn: 0.0349622	total: 673ms	remaining: 151ms
# 817:	learn: 0.0349306	total: 674ms	remaining: 150ms
# 818:	learn: 0.0348849	total: 675ms	remaining: 149ms
# 819:	learn: 0.0348144	total: 676ms	remaining: 148ms
# 820:	learn: 0.0348068	total: 676ms	remaining: 147ms
# 821:	learn: 0.0346469	total: 677ms	remaining: 147ms
# 822:	learn: 0.0345924	total: 678ms	remaining: 146ms
# 823:	learn: 0.0345452	total: 679ms	remaining: 145ms
# 824:	learn: 0.0345036	total: 679ms	remaining: 144ms
# 825:	learn: 0.0344425	total: 680ms	remaining: 143ms
# 826:	learn: 0.0344182	total: 681ms	remaining: 143ms
# 827:	learn: 0.0343965	total: 682ms	remaining: 142ms
# 828:	learn: 0.0343732	total: 683ms	remaining: 141ms
# 829:	learn: 0.0343223	total: 684ms	remaining: 140ms
# 830:	learn: 0.0342701	total: 684ms	remaining: 139ms
# 831:	learn: 0.0341853	total: 685ms	remaining: 138ms
# 832:	learn: 0.0341728	total: 686ms	remaining: 138ms
# 833:	learn: 0.0340877	total: 687ms	remaining: 137ms
# 834:	learn: 0.0340591	total: 688ms	remaining: 136ms
# 835:	learn: 0.0340483	total: 688ms	remaining: 135ms
# 836:	learn: 0.0339686	total: 689ms	remaining: 134ms
# 837:	learn: 0.0338895	total: 690ms	remaining: 133ms
# 838:	learn: 0.0338329	total: 691ms	remaining: 133ms
# 839:	learn: 0.0336831	total: 691ms	remaining: 132ms
# 840:	learn: 0.0336242	total: 692ms	remaining: 131ms
# 841:	learn: 0.0336048	total: 693ms	remaining: 130ms
# 842:	learn: 0.0336004	total: 694ms	remaining: 129ms
# 843:	learn: 0.0335580	total: 695ms	remaining: 128ms
# 844:	learn: 0.0335264	total: 695ms	remaining: 128ms
# 845:	learn: 0.0334780	total: 696ms	remaining: 127ms
# 846:	learn: 0.0334380	total: 697ms	remaining: 126ms
# 847:	learn: 0.0333651	total: 698ms	remaining: 125ms
# 848:	learn: 0.0332697	total: 699ms	remaining: 124ms
# 849:	learn: 0.0332048	total: 699ms	remaining: 123ms
# 850:	learn: 0.0331596	total: 700ms	remaining: 123ms
# 851:	learn: 0.0331116	total: 701ms	remaining: 122ms
# 852:	learn: 0.0330852	total: 702ms	remaining: 121ms
# 853:	learn: 0.0330431	total: 703ms	remaining: 120ms
# 854:	learn: 0.0330321	total: 704ms	remaining: 119ms
# 855:	learn: 0.0329696	total: 704ms	remaining: 118ms
# 856:	learn: 0.0329162	total: 705ms	remaining: 118ms
# 857:	learn: 0.0328625	total: 706ms	remaining: 117ms
# 858:	learn: 0.0328325	total: 707ms	remaining: 116ms
# 859:	learn: 0.0327928	total: 707ms	remaining: 115ms
# 860:	learn: 0.0327292	total: 708ms	remaining: 114ms
# 861:	learn: 0.0326763	total: 709ms	remaining: 114ms
# 862:	learn: 0.0326414	total: 710ms	remaining: 113ms
# 863:	learn: 0.0325707	total: 711ms	remaining: 112ms
# 864:	learn: 0.0325040	total: 711ms	remaining: 111ms
# 865:	learn: 0.0324663	total: 712ms	remaining: 110ms
# 866:	learn: 0.0323842	total: 713ms	remaining: 109ms
# 867:	learn: 0.0323288	total: 714ms	remaining: 109ms
# 868:	learn: 0.0322486	total: 715ms	remaining: 108ms
# 869:	learn: 0.0322474	total: 715ms	remaining: 107ms
# 870:	learn: 0.0321975	total: 716ms	remaining: 106ms
# 871:	learn: 0.0321190	total: 717ms	remaining: 105ms
# 872:	learn: 0.0320697	total: 718ms	remaining: 104ms
# 873:	learn: 0.0320072	total: 718ms	remaining: 104ms
# 874:	learn: 0.0319721	total: 719ms	remaining: 103ms
# 875:	learn: 0.0319140	total: 720ms	remaining: 102ms
# 876:	learn: 0.0318894	total: 721ms	remaining: 101ms
# 877:	learn: 0.0318647	total: 722ms	remaining: 100ms
# 878:	learn: 0.0318469	total: 722ms	remaining: 99.4ms
# 879:	learn: 0.0317939	total: 723ms	remaining: 98.6ms
# 880:	learn: 0.0317292	total: 724ms	remaining: 97.8ms
# 881:	learn: 0.0316625	total: 725ms	remaining: 97ms
# 882:	learn: 0.0315779	total: 725ms	remaining: 96.1ms
# 883:	learn: 0.0315304	total: 726ms	remaining: 95.3ms
# 884:	learn: 0.0314825	total: 727ms	remaining: 94.5ms
# 885:	learn: 0.0314595	total: 728ms	remaining: 93.7ms
# 886:	learn: 0.0314133	total: 729ms	remaining: 92.8ms
# 887:	learn: 0.0314077	total: 730ms	remaining: 92ms
# 888:	learn: 0.0313407	total: 730ms	remaining: 91.2ms
# 889:	learn: 0.0312779	total: 731ms	remaining: 90.4ms
# 890:	learn: 0.0311944	total: 732ms	remaining: 89.5ms
# 891:	learn: 0.0311392	total: 733ms	remaining: 88.7ms
# 892:	learn: 0.0309985	total: 734ms	remaining: 87.9ms
# 893:	learn: 0.0309642	total: 735ms	remaining: 87.1ms
# 894:	learn: 0.0309095	total: 735ms	remaining: 86.3ms
# 895:	learn: 0.0309080	total: 736ms	remaining: 85.4ms
# 896:	learn: 0.0308988	total: 737ms	remaining: 84.6ms
# 897:	learn: 0.0308509	total: 738ms	remaining: 83.8ms
# 898:	learn: 0.0307882	total: 739ms	remaining: 83ms
# 899:	learn: 0.0307079	total: 739ms	remaining: 82.1ms
# 900:	learn: 0.0306294	total: 740ms	remaining: 81.3ms
# 901:	learn: 0.0306232	total: 741ms	remaining: 80.5ms
# 902:	learn: 0.0305864	total: 742ms	remaining: 79.7ms
# 903:	learn: 0.0305505	total: 743ms	remaining: 78.9ms
# 904:	learn: 0.0304990	total: 743ms	remaining: 78ms
# 905:	learn: 0.0304876	total: 744ms	remaining: 77.2ms
# 906:	learn: 0.0304531	total: 745ms	remaining: 76.4ms
# 907:	learn: 0.0304342	total: 746ms	remaining: 75.5ms
# 908:	learn: 0.0303020	total: 746ms	remaining: 74.7ms
# 909:	learn: 0.0302573	total: 747ms	remaining: 73.9ms
# 910:	learn: 0.0302167	total: 748ms	remaining: 73.1ms
# 911:	learn: 0.0302060	total: 749ms	remaining: 72.3ms
# 912:	learn: 0.0301717	total: 750ms	remaining: 71.4ms
# 913:	learn: 0.0301368	total: 751ms	remaining: 70.6ms
# 914:	learn: 0.0301288	total: 751ms	remaining: 69.8ms
# 915:	learn: 0.0300831	total: 752ms	remaining: 69ms
# 916:	learn: 0.0300506	total: 753ms	remaining: 68.2ms
# 917:	learn: 0.0300266	total: 754ms	remaining: 67.3ms
# 918:	learn: 0.0299625	total: 755ms	remaining: 66.5ms
# 919:	learn: 0.0298916	total: 755ms	remaining: 65.7ms
# 920:	learn: 0.0298250	total: 756ms	remaining: 64.9ms
# 921:	learn: 0.0297654	total: 757ms	remaining: 64ms
# ...
# 703:	learn: 0.0348157	total: 608ms	remaining: 256ms
# 704:	learn: 0.0347227	total: 609ms	remaining: 255ms
# 705:	learn: 0.0346785	total: 610ms	remaining: 254ms
# 706:	learn: 0.0346613	total: 611ms	remaining: 253ms
# 707:	learn: 0.0345912	total: 612ms	remaining: 252ms
# 708:	learn: 0.0345248	total: 612ms	remaining: 251ms
# 709:	learn: 0.0344905	total: 613ms	remaining: 250ms
# 710:	learn: 0.0344554	total: 614ms	remaining: 250ms
# 711:	learn: 0.0344164	total: 615ms	remaining: 249ms
# 712:	learn: 0.0343613	total: 615ms	remaining: 248ms
# 713:	learn: 0.0343093	total: 616ms	remaining: 247ms
# 714:	learn: 0.0342660	total: 617ms	remaining: 246ms
# 715:	learn: 0.0341783	total: 618ms	remaining: 245ms
# 716:	learn: 0.0341084	total: 619ms	remaining: 244ms
# 717:	learn: 0.0340658	total: 619ms	remaining: 243ms
# 718:	learn: 0.0339218	total: 620ms	remaining: 242ms
# 719:	learn: 0.0338829	total: 621ms	remaining: 241ms
# 720:	learn: 0.0338371	total: 622ms	remaining: 241ms
# 721:	learn: 0.0337781	total: 623ms	remaining: 240ms
# 722:	learn: 0.0337522	total: 623ms	remaining: 239ms
# 723:	learn: 0.0337177	total: 624ms	remaining: 238ms
# 724:	learn: 0.0336811	total: 625ms	remaining: 237ms
# 725:	learn: 0.0335669	total: 626ms	remaining: 236ms
# 726:	learn: 0.0335120	total: 626ms	remaining: 235ms
# 727:	learn: 0.0334635	total: 627ms	remaining: 234ms
# 728:	learn: 0.0333978	total: 628ms	remaining: 233ms
# 729:	learn: 0.0333785	total: 629ms	remaining: 233ms
# 730:	learn: 0.0333595	total: 630ms	remaining: 232ms
# 731:	learn: 0.0332246	total: 630ms	remaining: 231ms
# 732:	learn: 0.0331861	total: 631ms	remaining: 230ms
# 733:	learn: 0.0331415	total: 632ms	remaining: 229ms
# 734:	learn: 0.0330984	total: 633ms	remaining: 228ms
# 735:	learn: 0.0330562	total: 634ms	remaining: 227ms
# 736:	learn: 0.0330052	total: 634ms	remaining: 226ms
# 737:	learn: 0.0328781	total: 635ms	remaining: 225ms
# 738:	learn: 0.0328562	total: 636ms	remaining: 225ms
# 739:	learn: 0.0328312	total: 637ms	remaining: 224ms
# 740:	learn: 0.0327991	total: 638ms	remaining: 223ms
# 741:	learn: 0.0327562	total: 638ms	remaining: 222ms
# 742:	learn: 0.0327113	total: 639ms	remaining: 221ms
# 743:	learn: 0.0326850	total: 640ms	remaining: 220ms
# 744:	learn: 0.0326374	total: 641ms	remaining: 219ms
# 745:	learn: 0.0326131	total: 642ms	remaining: 218ms
# 746:	learn: 0.0325803	total: 642ms	remaining: 218ms
# 747:	learn: 0.0324881	total: 643ms	remaining: 217ms
# 748:	learn: 0.0324576	total: 644ms	remaining: 216ms
# 749:	learn: 0.0324306	total: 645ms	remaining: 215ms
# 750:	learn: 0.0323743	total: 645ms	remaining: 214ms
# 751:	learn: 0.0323320	total: 646ms	remaining: 213ms
# 752:	learn: 0.0322282	total: 647ms	remaining: 212ms
# 753:	learn: 0.0321472	total: 648ms	remaining: 211ms
# 754:	learn: 0.0320906	total: 649ms	remaining: 211ms
# 755:	learn: 0.0320471	total: 650ms	remaining: 210ms
# 756:	learn: 0.0320196	total: 651ms	remaining: 209ms
# 757:	learn: 0.0319868	total: 651ms	remaining: 208ms
# 758:	learn: 0.0319160	total: 652ms	remaining: 207ms
# 759:	learn: 0.0318719	total: 653ms	remaining: 206ms
# 760:	learn: 0.0318329	total: 654ms	remaining: 205ms
# 761:	learn: 0.0317825	total: 655ms	remaining: 204ms
# 762:	learn: 0.0317502	total: 655ms	remaining: 204ms
# 763:	learn: 0.0317070	total: 656ms	remaining: 203ms
# 764:	learn: 0.0316868	total: 657ms	remaining: 202ms
# 765:	learn: 0.0316151	total: 658ms	remaining: 201ms
# 766:	learn: 0.0315594	total: 659ms	remaining: 200ms
# 767:	learn: 0.0315137	total: 659ms	remaining: 199ms
# 768:	learn: 0.0314860	total: 660ms	remaining: 198ms
# 769:	learn: 0.0314187	total: 661ms	remaining: 197ms
# 770:	learn: 0.0313451	total: 662ms	remaining: 197ms
# 771:	learn: 0.0313011	total: 663ms	remaining: 196ms
# 772:	learn: 0.0312936	total: 663ms	remaining: 195ms
# 773:	learn: 0.0312733	total: 664ms	remaining: 194ms
# 774:	learn: 0.0312129	total: 665ms	remaining: 193ms
# 775:	learn: 0.0311700	total: 666ms	remaining: 192ms
# 776:	learn: 0.0311117	total: 666ms	remaining: 191ms
# 777:	learn: 0.0310631	total: 667ms	remaining: 190ms
# 778:	learn: 0.0309164	total: 668ms	remaining: 190ms
# 779:	learn: 0.0308419	total: 669ms	remaining: 189ms
# 780:	learn: 0.0307424	total: 670ms	remaining: 188ms
# 781:	learn: 0.0306969	total: 670ms	remaining: 187ms
# 782:	learn: 0.0306523	total: 671ms	remaining: 186ms
# 783:	learn: 0.0306105	total: 672ms	remaining: 185ms
# 784:	learn: 0.0305757	total: 673ms	remaining: 184ms
# 785:	learn: 0.0305156	total: 674ms	remaining: 183ms
# 786:	learn: 0.0304963	total: 675ms	remaining: 183ms
# 787:	learn: 0.0304795	total: 675ms	remaining: 182ms
# 788:	learn: 0.0304573	total: 676ms	remaining: 181ms
# 789:	learn: 0.0304122	total: 677ms	remaining: 180ms
# 790:	learn: 0.0303566	total: 678ms	remaining: 179ms
# 791:	learn: 0.0303165	total: 678ms	remaining: 178ms
# 792:	learn: 0.0302704	total: 679ms	remaining: 177ms
# 793:	learn: 0.0302451	total: 680ms	remaining: 176ms
# 794:	learn: 0.0301933	total: 681ms	remaining: 176ms
# 795:	learn: 0.0301512	total: 681ms	remaining: 175ms
# 796:	learn: 0.0300156	total: 682ms	remaining: 174ms
# 797:	learn: 0.0299531	total: 683ms	remaining: 173ms
# 798:	learn: 0.0298936	total: 684ms	remaining: 172ms
# 799:	learn: 0.0298281	total: 685ms	remaining: 171ms
# 800:	learn: 0.0298103	total: 685ms	remaining: 170ms
# 801:	learn: 0.0297387	total: 686ms	remaining: 169ms
# 802:	learn: 0.0296986	total: 687ms	remaining: 169ms
# 803:	learn: 0.0296658	total: 688ms	remaining: 168ms
# 804:	learn: 0.0296170	total: 689ms	remaining: 167ms
# 805:	learn: 0.0295897	total: 690ms	remaining: 166ms
# 806:	learn: 0.0295289	total: 691ms	remaining: 165ms
# 807:	learn: 0.0294722	total: 692ms	remaining: 164ms
# 808:	learn: 0.0293848	total: 693ms	remaining: 164ms
# 809:	learn: 0.0293450	total: 694ms	remaining: 163ms
# 810:	learn: 0.0293196	total: 694ms	remaining: 162ms
# 811:	learn: 0.0292967	total: 695ms	remaining: 161ms
# 812:	learn: 0.0292614	total: 696ms	remaining: 160ms
# 813:	learn: 0.0292205	total: 697ms	remaining: 159ms
# 814:	learn: 0.0291444	total: 698ms	remaining: 158ms
# 815:	learn: 0.0291207	total: 699ms	remaining: 158ms
# 816:	learn: 0.0291037	total: 699ms	remaining: 157ms
# 817:	learn: 0.0290751	total: 700ms	remaining: 156ms
# 818:	learn: 0.0290446	total: 701ms	remaining: 155ms
# 819:	learn: 0.0290297	total: 702ms	remaining: 154ms
# 820:	learn: 0.0289521	total: 703ms	remaining: 153ms
# 821:	learn: 0.0289188	total: 704ms	remaining: 152ms
# 822:	learn: 0.0288777	total: 705ms	remaining: 152ms
# 823:	learn: 0.0288398	total: 706ms	remaining: 151ms
# 824:	learn: 0.0288129	total: 706ms	remaining: 150ms
# 825:	learn: 0.0287709	total: 707ms	remaining: 149ms
# 826:	learn: 0.0287438	total: 708ms	remaining: 148ms
# 827:	learn: 0.0287086	total: 709ms	remaining: 147ms
# 828:	learn: 0.0286722	total: 710ms	remaining: 146ms
# 829:	learn: 0.0285819	total: 710ms	remaining: 146ms
# 830:	learn: 0.0285317	total: 711ms	remaining: 145ms
# 831:	learn: 0.0284464	total: 712ms	remaining: 144ms
# 832:	learn: 0.0284140	total: 713ms	remaining: 143ms
# 833:	learn: 0.0283759	total: 713ms	remaining: 142ms
# 834:	learn: 0.0283371	total: 714ms	remaining: 141ms
# 835:	learn: 0.0283213	total: 715ms	remaining: 140ms
# 836:	learn: 0.0282753	total: 716ms	remaining: 139ms
# 837:	learn: 0.0282280	total: 717ms	remaining: 139ms
# 838:	learn: 0.0281926	total: 718ms	remaining: 138ms
# 839:	learn: 0.0281587	total: 718ms	remaining: 137ms
# 840:	learn: 0.0280776	total: 719ms	remaining: 136ms
# 841:	learn: 0.0280528	total: 720ms	remaining: 135ms
# 842:	learn: 0.0279985	total: 721ms	remaining: 134ms
# 843:	learn: 0.0279629	total: 721ms	remaining: 133ms
# 844:	learn: 0.0279429	total: 722ms	remaining: 132ms
# 845:	learn: 0.0278660	total: 723ms	remaining: 132ms
# 846:	learn: 0.0278121	total: 724ms	remaining: 131ms
# 847:	learn: 0.0277954	total: 724ms	remaining: 130ms
# 848:	learn: 0.0277650	total: 725ms	remaining: 129ms
# 849:	learn: 0.0277228	total: 726ms	remaining: 128ms
# 850:	learn: 0.0276991	total: 727ms	remaining: 127ms
# 851:	learn: 0.0276540	total: 728ms	remaining: 126ms
# 852:	learn: 0.0275986	total: 728ms	remaining: 126ms
# 853:	learn: 0.0275240	total: 729ms	remaining: 125ms
# 854:	learn: 0.0274698	total: 730ms	remaining: 124ms
# 855:	learn: 0.0274271	total: 731ms	remaining: 123ms
# 856:	learn: 0.0274017	total: 732ms	remaining: 122ms
# 857:	learn: 0.0273579	total: 732ms	remaining: 121ms
# 858:	learn: 0.0273164	total: 733ms	remaining: 120ms
# 859:	learn: 0.0272754	total: 734ms	remaining: 119ms
# 860:	learn: 0.0272419	total: 735ms	remaining: 119ms
# 861:	learn: 0.0271748	total: 736ms	remaining: 118ms
# 862:	learn: 0.0271372	total: 736ms	remaining: 117ms
# 863:	learn: 0.0270857	total: 737ms	remaining: 116ms
# 864:	learn: 0.0270514	total: 738ms	remaining: 115ms
# 865:	learn: 0.0270259	total: 739ms	remaining: 114ms
# 866:	learn: 0.0269839	total: 739ms	remaining: 113ms
# 867:	learn: 0.0269301	total: 740ms	remaining: 113ms
# 868:	learn: 0.0268829	total: 741ms	remaining: 112ms
# 869:	learn: 0.0268399	total: 742ms	remaining: 111ms
# 870:	learn: 0.0267896	total: 743ms	remaining: 110ms
# 871:	learn: 0.0267503	total: 744ms	remaining: 109ms
# 872:	learn: 0.0266990	total: 744ms	remaining: 108ms
# 873:	learn: 0.0266658	total: 745ms	remaining: 107ms
# 874:	learn: 0.0266187	total: 746ms	remaining: 107ms
# 875:	learn: 0.0265486	total: 747ms	remaining: 106ms
# 876:	learn: 0.0265358	total: 748ms	remaining: 105ms
# 877:	learn: 0.0264995	total: 748ms	remaining: 104ms
# 878:	learn: 0.0264502	total: 749ms	remaining: 103ms
# 879:	learn: 0.0264013	total: 750ms	remaining: 102ms
# 880:	learn: 0.0263706	total: 751ms	remaining: 101ms
# 881:	learn: 0.0263419	total: 752ms	remaining: 101ms
# 882:	learn: 0.0263128	total: 752ms	remaining: 99.7ms
# 883:	learn: 0.0262462	total: 753ms	remaining: 98.8ms
# 884:	learn: 0.0261998	total: 754ms	remaining: 98ms
# 885:	learn: 0.0261579	total: 755ms	remaining: 97.1ms
# 886:	learn: 0.0261434	total: 755ms	remaining: 96.2ms
# 887:	learn: 0.0261179	total: 756ms	remaining: 95.4ms
# 888:	learn: 0.0260718	total: 757ms	remaining: 94.5ms
# 889:	learn: 0.0260609	total: 758ms	remaining: 93.7ms
# 890:	learn: 0.0260511	total: 759ms	remaining: 92.8ms
# 891:	learn: 0.0259973	total: 760ms	remaining: 92ms
# 892:	learn: 0.0259586	total: 760ms	remaining: 91.1ms
# 893:	learn: 0.0259202	total: 761ms	remaining: 90.2ms
# 894:	learn: 0.0258540	total: 762ms	remaining: 89.4ms
# 895:	learn: 0.0258432	total: 763ms	remaining: 88.5ms
# 896:	learn: 0.0258339	total: 764ms	remaining: 87.7ms
# 897:	learn: 0.0257959	total: 764ms	remaining: 86.8ms
# 898:	learn: 0.0257598	total: 765ms	remaining: 86ms
# 899:	learn: 0.0257205	total: 766ms	remaining: 85.1ms
# 900:	learn: 0.0256771	total: 767ms	remaining: 84.3ms
# 901:	learn: 0.0256401	total: 768ms	remaining: 83.4ms
# 902:	learn: 0.0256156	total: 768ms	remaining: 82.5ms
# 903:	learn: 0.0255900	total: 769ms	remaining: 81.7ms
# 904:	learn: 0.0255438	total: 770ms	remaining: 80.8ms
# 905:	learn: 0.0255175	total: 771ms	remaining: 80ms
# 906:	learn: 0.0255057	total: 771ms	remaining: 79.1ms
# 907:	learn: 0.0254591	total: 772ms	remaining: 78.2ms
# 908:	learn: 0.0254221	total: 773ms	remaining: 77.4ms
# 909:	learn: 0.0254139	total: 774ms	remaining: 76.5ms
# 910:	learn: 0.0253539	total: 775ms	remaining: 75.7ms
# 911:	learn: 0.0253351	total: 776ms	remaining: 74.8ms
# 912:	learn: 0.0253241	total: 776ms	remaining: 74ms
# 913:	learn: 0.0252963	total: 777ms	remaining: 73.1ms
# 914:	learn: 0.0252367	total: 778ms	remaining: 72.3ms
# 915:	learn: 0.0252079	total: 779ms	remaining: 71.4ms
# 916:	learn: 0.0251994	total: 779ms	remaining: 70.5ms
# 917:	learn: 0.0251695	total: 780ms	remaining: 69.7ms
# 918:	learn: 0.0250638	total: 781ms	remaining: 68.8ms
# 919:	learn: 0.0250329	total: 782ms	remaining: 68ms
# 920:	learn: 0.0250091	total: 783ms	remaining: 67.1ms
# 921:	learn: 0.0249651	total: 783ms	remaining: 66.3ms
# 922:	learn: 0.0249524	total: 784ms	remaining: 65.4ms
# 923:	learn: 0.0249107	total: 785ms	remaining: 64.6ms
# 924:	learn: 0.0248740	total: 786ms	remaining: 63.7ms
# 925:	learn: 0.0248131	total: 787ms	remaining: 62.9ms
# 926:	learn: 0.0247792	total: 788ms	remaining: 62ms
# 927:	learn: 0.0247244	total: 788ms	remaining: 61.2ms
# 928:	learn: 0.0246833	total: 789ms	remaining: 60.3ms
# 929:	learn: 0.0246239	total: 790ms	remaining: 59.5ms
# 930:	learn: 0.0246130	total: 791ms	remaining: 58.6ms
# 931:	learn: 0.0246049	total: 791ms	remaining: 57.7ms
# 932:	learn: 0.0245970	total: 792ms	remaining: 56.9ms
# 933:	learn: 0.0245647	total: 793ms	remaining: 56ms
# 934:	learn: 0.0245313	total: 794ms	remaining: 55.2ms
# 935:	learn: 0.0244723	total: 795ms	remaining: 54.3ms
# 936:	learn: 0.0244432	total: 795ms	remaining: 53.5ms
# 937:	learn: 0.0244287	total: 796ms	remaining: 52.6ms
# 938:	learn: 0.0244130	total: 797ms	remaining: 51.8ms
# 939:	learn: 0.0243892	total: 798ms	remaining: 50.9ms
# 940:	learn: 0.0243792	total: 799ms	remaining: 50.1ms
# 941:	learn: 0.0243523	total: 799ms	remaining: 49.2ms
# 942:	learn: 0.0243322	total: 800ms	remaining: 48.4ms
# 943:	learn: 0.0242930	total: 801ms	remaining: 47.5ms
# 944:	learn: 0.0242746	total: 802ms	remaining: 46.7ms
# 945:	learn: 0.0242352	total: 803ms	remaining: 45.8ms
# 946:	learn: 0.0242000	total: 803ms	remaining: 45ms
# 947:	learn: 0.0241812	total: 804ms	remaining: 44.1ms
# 948:	learn: 0.0241652	total: 805ms	remaining: 43.3ms
# 949:	learn: 0.0241459	total: 806ms	remaining: 42.4ms
# 950:	learn: 0.0241213	total: 807ms	remaining: 41.6ms
# 951:	learn: 0.0240768	total: 807ms	remaining: 40.7ms
# 952:	learn: 0.0240693	total: 808ms	remaining: 39.9ms
# 953:	learn: 0.0240402	total: 809ms	remaining: 39ms
# 954:	learn: 0.0240107	total: 810ms	remaining: 38.1ms
# 955:	learn: 0.0239905	total: 810ms	remaining: 37.3ms
# 956:	learn: 0.0239785	total: 811ms	remaining: 36.4ms
# 957:	learn: 0.0239491	total: 812ms	remaining: 35.6ms
# 958:	learn: 0.0239428	total: 813ms	remaining: 34.7ms
# 959:	learn: 0.0239135	total: 814ms	remaining: 33.9ms
# 960:	learn: 0.0239059	total: 814ms	remaining: 33ms
# 961:	learn: 0.0238903	total: 815ms	remaining: 32.2ms
# 962:	learn: 0.0238827	total: 816ms	remaining: 31.4ms
# 963:	learn: 0.0238641	total: 817ms	remaining: 30.5ms
# 964:	learn: 0.0238237	total: 818ms	remaining: 29.7ms
# 965:	learn: 0.0238092	total: 818ms	remaining: 28.8ms
# 966:	learn: 0.0238023	total: 819ms	remaining: 28ms
# 967:	learn: 0.0237887	total: 820ms	remaining: 27.1ms
# 968:	learn: 0.0237650	total: 821ms	remaining: 26.3ms
# 969:	learn: 0.0237376	total: 821ms	remaining: 25.4ms
# 970:	learn: 0.0236987	total: 822ms	remaining: 24.6ms
# 971:	learn: 0.0236830	total: 823ms	remaining: 23.7ms
# 972:	learn: 0.0236644	total: 824ms	remaining: 22.9ms
# 973:	learn: 0.0236464	total: 825ms	remaining: 22ms
# 974:	learn: 0.0236074	total: 825ms	remaining: 21.2ms
# 975:	learn: 0.0235863	total: 826ms	remaining: 20.3ms
# 976:	learn: 0.0235639	total: 827ms	remaining: 19.5ms
# 977:	learn: 0.0235392	total: 828ms	remaining: 18.6ms
# 978:	learn: 0.0234791	total: 829ms	remaining: 17.8ms
# 979:	learn: 0.0234423	total: 830ms	remaining: 16.9ms
# 980:	learn: 0.0233903	total: 830ms	remaining: 16.1ms
# 981:	learn: 0.0233800	total: 831ms	remaining: 15.2ms
# 982:	learn: 0.0233686	total: 832ms	remaining: 14.4ms
# 983:	learn: 0.0233433	total: 833ms	remaining: 13.5ms
# 984:	learn: 0.0232879	total: 833ms	remaining: 12.7ms
# 985:	learn: 0.0232375	total: 834ms	remaining: 11.8ms
# 986:	learn: 0.0232061	total: 835ms	remaining: 11ms
# 987:	learn: 0.0231644	total: 836ms	remaining: 10.2ms
# 988:	learn: 0.0231110	total: 837ms	remaining: 9.3ms
# 989:	learn: 0.0230603	total: 837ms	remaining: 8.46ms
# 990:	learn: 0.0230226	total: 838ms	remaining: 7.61ms
# 991:	learn: 0.0230043	total: 839ms	remaining: 6.77ms
# 992:	learn: 0.0229683	total: 840ms	remaining: 5.92ms
# 993:	learn: 0.0229184	total: 841ms	remaining: 5.07ms
# 994:	learn: 0.0229009	total: 841ms	remaining: 4.23ms
# 995:	learn: 0.0228713	total: 842ms	remaining: 3.38ms
# 996:	learn: 0.0228498	total: 843ms	remaining: 2.54ms
# 997:	learn: 0.0228181	total: 844ms	remaining: 1.69ms
# 998:	learn: 0.0227862	total: 845ms	remaining: 845us
# 999:	learn: 0.0227497	total: 845ms	remaining: 0us
# SVM mean absolute error:  0.21556857131932508
# Linear Regression mean absolute error:  31574708513.996727
# Random Forest mean absolute error:  0.04142647058823548
# XGBoost mean absolute error:  0.04478300510618069
# Linear Regression mean absolute error:  31574708513.996727
# GradientBoosting Regressor mean absolute error:  0.07065985749796871
# Decision Tree Regressor mean absolute error:  0.029264705882353144
# Cat Boost Regressor mean absolute error:  0.04878898138180454

# %%
def fit_and_evaluate(reg, param) -> list:
    reg.set_params(**param)
    reg.fit(X_train, y_train)

    y_predict = reg.predict(X_test)
    r2 = r2_score(y_test, y_predict)
    mae = mean_absolute_error(y_test, y_predict)
    mse = mean_squared_error(y_test, y_predict)
    rmse = mean_squared_error(y_test, y_predict, squared=False)
        
    return [reg.__class__.__name__, r2, mae, mse, rmse, param.keys(), param.values()]

# %%
from sklearn.metrics import (mean_absolute_error, mean_squared_error, r2_score)
import random 
import sys

RANDOM_SEED = 12345
random.seed(RANDOM_SEED)

list_grid = []

reg = RandomForestRegressor(random_state=RANDOM_SEED, n_jobs=-3)
print(reg.__class__.__name__)
for max_depth in np.arange(3, 16, 1):
        sys.stdout.write(f"\rmax_depth: {max_depth}/15...")
        for n_estimators in np.arange(5, 20, 1):
                param = {"max_depth": max_depth,
                        "n_estimators": n_estimators}
                list_grid.append(fit_and_evaluate(reg, param))

                
reg = XGBRegressor(random_state=RANDOM_SEED, n_jobs=-3, verbosity=0)
print()
print(reg.__class__.__name__)
for max_depth in np.arange(3, 11, 1):
        sys.stdout.write(f"\rmax_depth: {max_depth}/10...")
        for n_estimators in [10, 20, 50, 100]:
                for learning_rate in [0.1, 0.2, 0.3]:
                        for subsample in np.arange(0.4, 1.01, 0.1):
                                for colsample_bytree in np.arange(0.4, 1.01, 0.1): 
                                        param = {"max_depth": max_depth,
                                                "n_estimators": n_estimators,
                                                "learning_rate": learning_rate,
                                                "subsample": subsample, 
                                                "colsample_bytree": colsample_bytree}
                                        list_grid.append(fit_and_evaluate(reg, param))

# %%
reg_df = pd.DataFrame(data=list_grid, columns=["reg", "R2", "MAE", "MSE", "RMSE", "param.keys", "param.values"], index=None)
reg_df.sort_values(by=["R2"], ascending=False, inplace=True)

# %%
reg_df[reg_df['reg'] == "RandomForestRegressor"].head(10)

# %%
reg_df[reg_df['reg'] == "XGBRegressor"].head(10)

# %%
xgb_df = reg_df[reg_df['reg'] == "XGBRegressor"].head(10)
xgb_df['param.keys'] = xgb_df['param.keys'].apply(lambda x: list(x))
xgb_df['param.values'] = xgb_df['param.values'].apply(lambda x: list(x))

parameters_list = []
for keys,values in zip(xgb_df['param.keys'],xgb_df['param.values']):
    reg = XGBRegressor(random_state=RANDOM_SEED, n_jobs=-3, verbosity=0, **dict(zip(keys,values)))
    reg.fit(X_train, y_train) 
    y_pred = reg.predict(X_test)
    print(dict(zip(keys,values)))
    print(r2_score(y_test, y_pred))
    print()

# %%
reg = XGBRegressor(random_state=RANDOM_SEED, n_jobs=-3, verbosity=0, max_depth=9, n_estimators=100, learning_rate=0.2, subsample=0.6, colsample_bytree=0.9999999999999999)
reg.fit(X_train, y_train) 
y_pred = reg.predict(X_test)

r2_score(y_test, y_pred)

# %%
top_features = pd.Series(reg.feature_importances_, index = matches_df.drop('Effectiveness',axis = 1).columns).sort_values()
top_features.plot(kind="barh", figsize=(15, 10), title="Top Features")
plt.show()

# %%
rf_df = reg_df[reg_df['reg'] == "RandomForestRegressor"].head(10)
rf_df['param.keys'] = rf_df['param.keys'].apply(lambda x: list(x))
rf_df['param.values'] = rf_df['param.values'].apply(lambda x: list(x))

parameters_list = []
for keys,values in zip(rf_df['param.keys'],rf_df['param.values']):
    reg = RandomForestRegressor(random_state=RANDOM_SEED, n_jobs=-3, **dict(zip(keys,values)))
    reg.fit(X_train, y_train) 
    y_pred = reg.predict(X_test)
    print(dict(zip(keys,values)))
    print(r2_score(y_test, y_pred))
    print()

# %%
reg = RandomForestRegressor(random_state=RANDOM_SEED, n_jobs = -3, max_depth = 8, n_estimators = 9)
reg.fit(X_train, y_train) 
y_pred = reg.predict(X_test)

r2_score(y_test, y_pred)

# %%
top_features = pd.Series(reg.feature_importances_, index = matches_df.drop('Effectiveness',axis = 1).columns).sort_values()
top_features.plot(kind="barh", figsize=(15, 10), title="Top Features")
plt.show()

# %%
from sklearn.model_selection import GridSearchCV

param_grid = {
    'max_depth': [None, 5, 10],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4]
}

grid_search = GridSearchCV(DecisionTreeRegressor(), param_grid, cv=5)

grid_search.fit(X_train, y_train)

best_params = grid_search.best_params_
print("Best Hyperparameters:", best_params)

# %%
reg = DecisionTreeRegressor(random_state=RANDOM_SEED, **best_params)
reg.fit(X_train, y_train) 
y_pred = reg.predict(X_test)

r2_score(y_test, y_pred)

# %%
top_features = pd.Series(reg.feature_importances_, index = matches_df.drop('Effectiveness',axis = 1).columns).sort_values()
top_features.plot(kind="barh", figsize=(15, 10), title="Top Features")
plt.show()

# %%
parameters = {'depth' : [6,8,10],'learning_rate' : [0.01, 0.05, 0.1], 'iterations' : [30, 50, 100]}
grid = GridSearchCV(estimator = cb.CatBoostRegressor(), param_grid = parameters, cv = 2, n_jobs=-1)
grid.fit(X_train, y_train)

print(" Results from Grid Search " )
print("\n The best estimator across ALL searched params:\n", grid.best_estimator_)
print("\n The best score across ALL searched params:\n", grid.best_score_)
print("\n The best parameters across ALL searched params:\n", grid.best_params_)

# %%
reg = cb.CatBoostRegressor(random_state=RANDOM_SEED, **grid.best_params_)
reg.fit(X_train, y_train) 
y_pred = reg.predict(X_test)

r2_score(y_test, y_pred)

# %%
top_features = pd.Series(reg.feature_importances_, index = matches_df.drop('Effectiveness',axis = 1).columns).sort_values()
top_features.plot(kind="barh", figsize=(15, 10), title="Top Features")
plt.show()

# %%
from keras.models import Sequential
from keras.layers import Dense
from scikeras.wrappers import KerasRegressor
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold

matches_df.to_csv('matches_df.csv')

dataframe = pd.read_csv("matches_df.csv", header=None)
dataframe = dataframe[1:]
dataset = dataframe.values

X = dataset[:,[i for i in range(25) if i!=13]]
Y = dataset[:,13]

def baseline_model():
    model = Sequential()
    model.add(Dense(24, input_shape=(24,), kernel_initializer='normal', activation='relu'))
    model.add(Dense(1, kernel_initializer='normal'))
    model.compile(loss='mean_squared_error', optimizer='adam')
    return model

estimator = KerasRegressor(model=baseline_model, epochs=100, batch_size=5, verbose=0)
kfold = KFold(n_splits=10)
results = cross_val_score(estimator, X, Y, cv=kfold, scoring='neg_mean_squared_error')
print("Baseline: %.2f (%.2f) MSE" % (results.mean(), results.std()))

# %%
from sklearn.pipeline import Pipeline
estimators = []
estimators.append(('standardize', StandardScaler()))
estimators.append(('mlp', KerasRegressor(model=baseline_model, epochs=50, batch_size=5, verbose=0)))
pipeline = Pipeline(estimators)
kfold = KFold(n_splits=10)
results = cross_val_score(pipeline, X, Y, cv=kfold, scoring='neg_mean_squared_error')
print("Standardized: %.2f (%.2f) MSE" % (results.mean(), results.std()))

# %%
dataframe = pd.read_csv("matches_df.csv", header=None)
dataframe = dataframe[1:]
dataset = dataframe.values

X = dataset[:,[i for i in range(25) if i!=13]]
y = dataset[:,13]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout
from sklearn.metrics import r2_score
from keras.optimizers import Adam
import keras
from keras.callbacks import EarlyStopping
import pandas as pd 

model = Sequential()
model.add(Dense(128, activation="relu", input_dim=6))
model.add(Dense(32, activation="relu"))
model.add(Dense(8, activation="relu"))

model.add(Dense(1, activation="linear"))

model.compile(loss='mean_squared_error', optimizer=Adam(lr=1e-3, decay=1e-3 / 200))

es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=200)

history = model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=10000000, batch_size=100, verbose=2, callbacks=[es])

PredTestSet = model.predict(X1)
PredValSet = model.predict(X2)

numpy.savetxt("trainresults.csv", PredTestSet, delimiter=",")
numpy.savetxt("valresults.csv", PredValSet, delimiter=",")
